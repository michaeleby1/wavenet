# %% [markdown]
# <a href="https://colab.research.google.com/github/michaeleby1/wavenet/blob/master/wavenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !cd gdrive/My\ Drive/ && git clone https://github.com/michaeleby1/tensorflow-wavenet
# Out:
# Cloning into 'tensorflow-wavenet'...
# remote: Enumerating objects: 918, done.
# remote: Total 918 (delta 0), reused 0 (delta 0), pack-reused 918
# Receiving objects: 100% (918/918), 344.09 KiB | 472.00 KiB/s, done.
# Resolving deltas: 100% (525/525), done.

# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.6/dist-packages (0.6.3)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.6/dist-packages (from librosa) (1.12.0)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (1.18.5)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: resampy>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (0.2.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (0.22.2.post1)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (2.1.8)
# Requirement already satisfied: numba>=0.38.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (0.48.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (1.4.1)
# Requirement already satisfied: joblib>=0.12 in /usr/local/lib/python3.6/dist-packages (from librosa) (0.15.1)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba>=0.38.0->librosa) (0.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba>=0.38.0->librosa) (47.3.1)

# %%
##make sure tensorflow sees gpu
import tensorflow as tf

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
##downsample audio to 8k hz
import librosa   

y, s = librosa.load('gdrive/My Drive/guitar/spencerhateus.wav', sr=8000)
librosa.output.write_wav('gdrive/My Drive/guitar/spencerhateus.wav', y, s)

# %%
# !cd gdrive/My\ Drive/tensorflow-wavenet-new && python train.py --data_dir=/content/gdrive/My\ Drive\/guitar/ --silence_threshold=0.3 --sample_size=16000 --num_steps=9250
# Out:
# Streaming output truncated to the last 5000 lines.
# step 4872 - loss = 2.415, (0.147 sec/step)
# step 4873 - loss = 2.433, (0.149 sec/step)
# step 4874 - loss = 2.192, (0.149 sec/step)
# step 4875 - loss = 2.363, (0.149 sec/step)
# step 4876 - loss = 2.511, (0.148 sec/step)
# step 4877 - loss = 2.409, (0.147 sec/step)
# step 4878 - loss = 2.230, (0.150 sec/step)
# step 4879 - loss = 2.468, (0.147 sec/step)
# step 4880 - loss = 2.543, (0.147 sec/step)
# step 4881 - loss = 2.305, (0.147 sec/step)
# step 4882 - loss = 2.416, (0.148 sec/step)
# step 4883 - loss = 2.553, (0.162 sec/step)
# step 4884 - loss = 2.577, (0.148 sec/step)
# step 4885 - loss = 2.453, (0.148 sec/step)
# step 4886 - loss = 2.358, (0.148 sec/step)
# step 4887 - loss = 2.187, (0.148 sec/step)
# step 4888 - loss = 2.531, (0.148 sec/step)
# step 4889 - loss = 2.505, (0.148 sec/step)
# step 4890 - loss = 2.590, (0.148 sec/step)
# step 4891 - loss = 2.595, (0.147 sec/step)
# step 4892 - loss = 2.419, (0.150 sec/step)
# step 4893 - loss = 2.443, (0.148 sec/step)
# step 4894 - loss = 2.539, (0.148 sec/step)
# step 4895 - loss = 2.356, (0.147 sec/step)
# step 4896 - loss = 2.431, (0.150 sec/step)
# step 4897 - loss = 2.488, (0.148 sec/step)
# step 4898 - loss = 2.435, (0.147 sec/step)
# step 4899 - loss = 2.237, (0.148 sec/step)
# step 4900 - loss = 2.349, (0.148 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 4901 - loss = 2.683, (0.149 sec/step)
# step 4902 - loss = 2.436, (0.148 sec/step)
# step 4903 - loss = 2.537, (0.149 sec/step)
# step 4904 - loss = 2.466, (0.149 sec/step)
# step 4905 - loss = 2.540, (0.151 sec/step)
# step 4906 - loss = 2.381, (0.148 sec/step)
# step 4907 - loss = 2.515, (0.148 sec/step)
# step 4908 - loss = 2.406, (0.148 sec/step)
# step 4909 - loss = 2.449, (0.147 sec/step)
# step 4910 - loss = 2.201, (0.147 sec/step)
# step 4911 - loss = 2.469, (0.149 sec/step)
# step 4912 - loss = 2.472, (0.147 sec/step)
# step 4913 - loss = 2.214, (0.147 sec/step)
# step 4914 - loss = 2.585, (0.147 sec/step)
# step 4915 - loss = 2.352, (0.147 sec/step)
# step 4916 - loss = 2.545, (0.148 sec/step)
# step 4917 - loss = 2.469, (0.147 sec/step)
# step 4918 - loss = 2.537, (0.147 sec/step)
# step 4919 - loss = 2.355, (0.151 sec/step)
# step 4920 - loss = 2.248, (0.148 sec/step)
# step 4921 - loss = 2.094, (0.157 sec/step)
# step 4922 - loss = 2.424, (0.148 sec/step)
# step 4923 - loss = 2.508, (0.148 sec/step)
# step 4924 - loss = 2.396, (0.148 sec/step)
# step 4925 - loss = 2.434, (0.149 sec/step)
# step 4926 - loss = 2.288, (0.148 sec/step)
# step 4927 - loss = 2.527, (0.150 sec/step)
# step 4928 - loss = 2.343, (0.148 sec/step)
# step 4929 - loss = 2.238, (0.148 sec/step)
# step 4930 - loss = 2.268, (0.148 sec/step)
# step 4931 - loss = 2.494, (0.147 sec/step)
# step 4932 - loss = 2.512, (0.147 sec/step)
# step 4933 - loss = 2.527, (0.148 sec/step)
# step 4934 - loss = 2.494, (0.148 sec/step)
# step 4935 - loss = 2.180, (0.147 sec/step)
# step 4936 - loss = 2.625, (0.147 sec/step)
# step 4937 - loss = 2.502, (0.148 sec/step)
# step 4938 - loss = 2.535, (0.148 sec/step)
# step 4939 - loss = 2.393, (0.148 sec/step)
# step 4940 - loss = 2.449, (0.155 sec/step)
# step 4941 - loss = 2.494, (0.148 sec/step)
# step 4942 - loss = 2.436, (0.149 sec/step)
# step 4943 - loss = 2.454, (0.147 sec/step)
# step 4944 - loss = 2.265, (0.148 sec/step)
# step 4945 - loss = 2.489, (0.147 sec/step)
# step 4946 - loss = 2.502, (0.148 sec/step)
# step 4947 - loss = 2.490, (0.147 sec/step)
# step 4948 - loss = 2.299, (0.148 sec/step)
# step 4949 - loss = 2.417, (0.147 sec/step)
# step 4950 - loss = 2.397, (0.147 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 4951 - loss = 2.514, (0.150 sec/step)
# step 4952 - loss = 2.556, (0.148 sec/step)
# step 4953 - loss = 2.461, (0.149 sec/step)
# step 4954 - loss = 2.418, (0.147 sec/step)
# step 4955 - loss = 2.369, (0.147 sec/step)
# step 4956 - loss = 2.037, (0.149 sec/step)
# step 4957 - loss = 2.326, (0.148 sec/step)
# step 4958 - loss = 2.423, (0.148 sec/step)
# step 4959 - loss = 2.344, (0.148 sec/step)
# step 4960 - loss = 2.470, (0.147 sec/step)
# step 4961 - loss = 2.384, (0.148 sec/step)
# step 4962 - loss = 2.646, (0.147 sec/step)
# step 4963 - loss = 2.407, (0.149 sec/step)
# step 4964 - loss = 2.414, (0.148 sec/step)
# step 4965 - loss = 2.436, (0.148 sec/step)
# step 4966 - loss = 2.620, (0.149 sec/step)
# step 4967 - loss = 2.434, (0.148 sec/step)
# step 4968 - loss = 2.551, (0.148 sec/step)
# step 4969 - loss = 2.410, (0.148 sec/step)
# step 4970 - loss = 2.332, (0.148 sec/step)
# step 4971 - loss = 2.468, (0.148 sec/step)
# step 4972 - loss = 2.487, (0.147 sec/step)
# step 4973 - loss = 2.240, (0.147 sec/step)
# step 4974 - loss = 2.373, (0.147 sec/step)
# step 4975 - loss = 2.312, (0.147 sec/step)
# step 4976 - loss = 2.466, (0.148 sec/step)
# step 4977 - loss = 2.514, (0.149 sec/step)
# step 4978 - loss = 2.527, (0.147 sec/step)
# step 4979 - loss = 2.300, (0.148 sec/step)
# step 4980 - loss = 2.406, (0.147 sec/step)
# step 4981 - loss = 2.401, (0.148 sec/step)
# step 4982 - loss = 2.435, (0.147 sec/step)
# step 4983 - loss = 2.511, (0.148 sec/step)
# step 4984 - loss = 2.282, (0.148 sec/step)
# step 4985 - loss = 2.355, (0.148 sec/step)
# step 4986 - loss = 2.227, (0.148 sec/step)
# step 4987 - loss = 2.433, (0.148 sec/step)
# step 4988 - loss = 2.429, (0.148 sec/step)
# step 4989 - loss = 2.371, (0.148 sec/step)
# step 4990 - loss = 2.555, (0.149 sec/step)
# step 4991 - loss = 2.346, (0.148 sec/step)
# step 4992 - loss = 2.172, (0.149 sec/step)
# step 4993 - loss = 2.468, (0.147 sec/step)
# step 4994 - loss = 2.425, (0.148 sec/step)
# step 4995 - loss = 2.291, (0.149 sec/step)
# step 4996 - loss = 2.448, (0.147 sec/step)
# step 4997 - loss = 2.564, (0.147 sec/step)
# step 4998 - loss = 2.458, (0.147 sec/step)
# step 4999 - loss = 2.443, (0.147 sec/step)
# step 5000 - loss = 2.441, (0.149 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5001 - loss = 2.434, (0.148 sec/step)
# step 5002 - loss = 2.324, (0.147 sec/step)
# step 5003 - loss = 2.273, (0.147 sec/step)
# step 5004 - loss = 2.461, (0.147 sec/step)
# step 5005 - loss = 2.557, (0.147 sec/step)
# step 5006 - loss = 2.647, (0.147 sec/step)
# step 5007 - loss = 2.401, (0.147 sec/step)
# step 5008 - loss = 2.625, (0.147 sec/step)
# step 5009 - loss = 2.572, (0.147 sec/step)
# step 5010 - loss = 2.412, (0.147 sec/step)
# step 5011 - loss = 2.646, (0.149 sec/step)
# step 5012 - loss = 2.564, (0.148 sec/step)
# step 5013 - loss = 2.488, (0.148 sec/step)
# step 5014 - loss = 2.372, (0.148 sec/step)
# step 5015 - loss = 2.199, (0.149 sec/step)
# step 5016 - loss = 2.307, (0.148 sec/step)
# step 5017 - loss = 2.283, (0.148 sec/step)
# step 5018 - loss = 2.462, (0.147 sec/step)
# step 5019 - loss = 2.487, (0.147 sec/step)
# step 5020 - loss = 2.372, (0.148 sec/step)
# step 5021 - loss = 2.303, (0.148 sec/step)
# step 5022 - loss = 2.423, (0.148 sec/step)
# step 5023 - loss = 2.500, (0.147 sec/step)
# step 5024 - loss = 2.396, (0.153 sec/step)
# step 5025 - loss = 2.322, (0.147 sec/step)
# step 5026 - loss = 2.241, (0.148 sec/step)
# step 5027 - loss = 2.383, (0.149 sec/step)
# step 5028 - loss = 2.368, (0.147 sec/step)
# step 5029 - loss = 2.531, (0.149 sec/step)
# step 5030 - loss = 2.483, (0.148 sec/step)
# step 5031 - loss = 2.523, (0.148 sec/step)
# step 5032 - loss = 2.476, (0.154 sec/step)
# step 5033 - loss = 2.459, (0.147 sec/step)
# step 5034 - loss = 2.456, (0.149 sec/step)
# step 5035 - loss = 2.261, (0.148 sec/step)
# step 5036 - loss = 2.484, (0.148 sec/step)
# step 5037 - loss = 2.560, (0.148 sec/step)
# step 5038 - loss = 2.586, (0.147 sec/step)
# step 5039 - loss = 2.411, (0.147 sec/step)
# step 5040 - loss = 2.353, (0.147 sec/step)
# step 5041 - loss = 2.560, (0.148 sec/step)
# step 5042 - loss = 2.383, (0.147 sec/step)
# step 5043 - loss = 2.043, (0.148 sec/step)
# step 5044 - loss = 2.204, (0.148 sec/step)
# step 5045 - loss = 2.444, (0.148 sec/step)
# step 5046 - loss = 2.247, (0.152 sec/step)
# step 5047 - loss = 2.602, (0.147 sec/step)
# step 5048 - loss = 2.506, (0.147 sec/step)
# step 5049 - loss = 2.353, (0.147 sec/step)
# step 5050 - loss = 2.454, (0.148 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5051 - loss = 2.485, (0.149 sec/step)
# step 5052 - loss = 2.492, (0.148 sec/step)
# step 5053 - loss = 2.443, (0.150 sec/step)
# step 5054 - loss = 2.327, (0.148 sec/step)
# step 5055 - loss = 2.456, (0.148 sec/step)
# step 5056 - loss = 2.350, (0.147 sec/step)
# step 5057 - loss = 2.547, (0.148 sec/step)
# step 5058 - loss = 2.457, (0.148 sec/step)
# step 5059 - loss = 2.532, (0.147 sec/step)
# step 5060 - loss = 2.381, (0.148 sec/step)
# step 5061 - loss = 2.417, (0.147 sec/step)
# step 5062 - loss = 2.415, (0.147 sec/step)
# step 5063 - loss = 2.165, (0.147 sec/step)
# step 5064 - loss = 2.250, (0.147 sec/step)
# step 5065 - loss = 2.492, (0.148 sec/step)
# step 5066 - loss = 2.502, (0.150 sec/step)
# step 5067 - loss = 2.400, (0.148 sec/step)
# step 5068 - loss = 2.446, (0.149 sec/step)
# step 5069 - loss = 2.400, (0.148 sec/step)
# step 5070 - loss = 2.554, (0.147 sec/step)
# step 5071 - loss = 2.512, (0.148 sec/step)
# step 5072 - loss = 2.458, (0.148 sec/step)
# step 5073 - loss = 2.441, (0.147 sec/step)
# step 5074 - loss = 2.396, (0.148 sec/step)
# step 5075 - loss = 2.423, (0.147 sec/step)
# step 5076 - loss = 2.451, (0.146 sec/step)
# step 5077 - loss = 2.594, (0.147 sec/step)
# step 5078 - loss = 2.560, (0.147 sec/step)
# step 5079 - loss = 2.455, (0.148 sec/step)
# step 5080 - loss = 2.234, (0.147 sec/step)
# step 5081 - loss = 2.773, (0.149 sec/step)
# step 5082 - loss = 2.723, (0.147 sec/step)
# step 5083 - loss = 2.672, (0.146 sec/step)
# step 5084 - loss = 2.534, (0.148 sec/step)
# step 5085 - loss = 2.495, (0.147 sec/step)
# step 5086 - loss = 2.534, (0.148 sec/step)
# step 5087 - loss = 2.516, (0.147 sec/step)
# step 5088 - loss = 2.437, (0.147 sec/step)
# step 5089 - loss = 2.623, (0.149 sec/step)
# step 5090 - loss = 2.434, (0.148 sec/step)
# step 5091 - loss = 2.518, (0.147 sec/step)
# step 5092 - loss = 2.441, (0.147 sec/step)
# step 5093 - loss = 2.578, (0.148 sec/step)
# step 5094 - loss = 2.372, (0.148 sec/step)
# step 5095 - loss = 2.460, (0.147 sec/step)
# step 5096 - loss = 2.604, (0.147 sec/step)
# step 5097 - loss = 2.348, (0.151 sec/step)
# step 5098 - loss = 2.473, (0.148 sec/step)
# step 5099 - loss = 2.458, (0.148 sec/step)
# step 5100 - loss = 2.296, (0.148 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5101 - loss = 2.585, (0.149 sec/step)
# step 5102 - loss = 2.409, (0.148 sec/step)
# step 5103 - loss = 2.360, (0.148 sec/step)
# step 5104 - loss = 2.209, (0.148 sec/step)
# step 5105 - loss = 2.585, (0.148 sec/step)
# step 5106 - loss = 2.684, (0.147 sec/step)
# step 5107 - loss = 2.373, (0.149 sec/step)
# step 5108 - loss = 2.450, (0.147 sec/step)
# step 5109 - loss = 2.185, (0.147 sec/step)
# step 5110 - loss = 2.342, (0.148 sec/step)
# step 5111 - loss = 2.469, (0.147 sec/step)
# step 5112 - loss = 2.386, (0.147 sec/step)
# step 5113 - loss = 2.498, (0.147 sec/step)
# step 5114 - loss = 2.283, (0.148 sec/step)
# step 5115 - loss = 2.397, (0.148 sec/step)
# step 5116 - loss = 2.203, (0.148 sec/step)
# step 5117 - loss = 2.405, (0.148 sec/step)
# step 5118 - loss = 2.186, (0.150 sec/step)
# step 5119 - loss = 2.302, (0.148 sec/step)
# step 5120 - loss = 2.471, (0.148 sec/step)
# step 5121 - loss = 2.345, (0.147 sec/step)
# step 5122 - loss = 2.330, (0.147 sec/step)
# step 5123 - loss = 2.614, (0.147 sec/step)
# step 5124 - loss = 2.535, (0.147 sec/step)
# step 5125 - loss = 2.305, (0.147 sec/step)
# step 5126 - loss = 2.549, (0.147 sec/step)
# step 5127 - loss = 2.325, (0.147 sec/step)
# step 5128 - loss = 2.299, (0.147 sec/step)
# step 5129 - loss = 2.622, (0.151 sec/step)
# step 5130 - loss = 2.395, (0.148 sec/step)
# step 5131 - loss = 2.135, (0.148 sec/step)
# step 5132 - loss = 2.374, (0.148 sec/step)
# step 5133 - loss = 2.466, (0.149 sec/step)
# step 5134 - loss = 2.404, (0.147 sec/step)
# step 5135 - loss = 2.523, (0.147 sec/step)
# step 5136 - loss = 2.413, (0.148 sec/step)
# step 5137 - loss = 2.248, (0.149 sec/step)
# step 5138 - loss = 2.493, (0.148 sec/step)
# step 5139 - loss = 2.424, (0.147 sec/step)
# step 5140 - loss = 2.465, (0.147 sec/step)
# step 5141 - loss = 2.496, (0.147 sec/step)
# step 5142 - loss = 2.500, (0.149 sec/step)
# step 5143 - loss = 2.202, (0.148 sec/step)
# step 5144 - loss = 2.428, (0.147 sec/step)
# step 5145 - loss = 2.514, (0.148 sec/step)
# step 5146 - loss = 2.365, (0.147 sec/step)
# step 5147 - loss = 2.607, (0.147 sec/step)
# step 5148 - loss = 2.657, (0.147 sec/step)
# step 5149 - loss = 2.489, (0.148 sec/step)
# step 5150 - loss = 2.241, (0.149 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5151 - loss = 2.590, (0.149 sec/step)
# step 5152 - loss = 2.385, (0.148 sec/step)
# step 5153 - loss = 2.622, (0.148 sec/step)
# step 5154 - loss = 2.568, (0.148 sec/step)
# step 5155 - loss = 2.600, (0.148 sec/step)
# step 5156 - loss = 2.739, (0.149 sec/step)
# step 5157 - loss = 2.571, (0.147 sec/step)
# step 5158 - loss = 2.605, (0.147 sec/step)
# step 5159 - loss = 2.703, (0.147 sec/step)
# step 5160 - loss = 2.491, (0.147 sec/step)
# step 5161 - loss = 2.342, (0.149 sec/step)
# step 5162 - loss = 2.512, (0.149 sec/step)
# step 5163 - loss = 2.347, (0.149 sec/step)
# step 5164 - loss = 2.500, (0.147 sec/step)
# step 5165 - loss = 2.348, (0.147 sec/step)
# step 5166 - loss = 2.363, (0.148 sec/step)
# step 5167 - loss = 2.545, (0.147 sec/step)
# step 5168 - loss = 2.466, (0.147 sec/step)
# step 5169 - loss = 2.428, (0.148 sec/step)
# step 5170 - loss = 2.609, (0.148 sec/step)
# step 5171 - loss = 2.388, (0.147 sec/step)
# step 5172 - loss = 2.476, (0.147 sec/step)
# step 5173 - loss = 2.513, (0.148 sec/step)
# step 5174 - loss = 2.379, (0.146 sec/step)
# step 5175 - loss = 2.360, (0.147 sec/step)
# step 5176 - loss = 2.393, (0.147 sec/step)
# step 5177 - loss = 2.469, (0.148 sec/step)
# step 5178 - loss = 2.463, (0.148 sec/step)
# step 5179 - loss = 2.528, (0.148 sec/step)
# step 5180 - loss = 2.397, (0.147 sec/step)
# step 5181 - loss = 2.359, (0.152 sec/step)
# step 5182 - loss = 2.423, (0.147 sec/step)
# step 5183 - loss = 2.523, (0.149 sec/step)
# step 5184 - loss = 2.513, (0.147 sec/step)
# step 5185 - loss = 2.431, (0.147 sec/step)
# step 5186 - loss = 2.399, (0.147 sec/step)
# step 5187 - loss = 2.531, (0.147 sec/step)
# step 5188 - loss = 2.556, (0.147 sec/step)
# step 5189 - loss = 2.251, (0.149 sec/step)
# step 5190 - loss = 2.417, (0.148 sec/step)
# step 5191 - loss = 2.599, (0.148 sec/step)
# step 5192 - loss = 2.528, (0.148 sec/step)
# step 5193 - loss = 2.484, (0.147 sec/step)
# step 5194 - loss = 2.336, (0.150 sec/step)
# step 5195 - loss = 2.208, (0.148 sec/step)
# step 5196 - loss = 2.537, (0.148 sec/step)
# step 5197 - loss = 2.429, (0.148 sec/step)
# step 5198 - loss = 2.456, (0.148 sec/step)
# step 5199 - loss = 2.063, (0.147 sec/step)
# step 5200 - loss = 2.378, (0.149 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5201 - loss = 2.653, (0.149 sec/step)
# step 5202 - loss = 2.656, (0.147 sec/step)
# step 5203 - loss = 2.520, (0.148 sec/step)
# step 5204 - loss = 2.453, (0.148 sec/step)
# step 5205 - loss = 2.028, (0.148 sec/step)
# step 5206 - loss = 2.579, (0.149 sec/step)
# step 5207 - loss = 2.578, (0.148 sec/step)
# step 5208 - loss = 2.410, (0.149 sec/step)
# step 5209 - loss = 2.568, (0.148 sec/step)
# step 5210 - loss = 2.566, (0.148 sec/step)
# step 5211 - loss = 2.509, (0.147 sec/step)
# step 5212 - loss = 2.560, (0.148 sec/step)
# step 5213 - loss = 2.538, (0.147 sec/step)
# step 5214 - loss = 2.460, (0.150 sec/step)
# step 5215 - loss = 2.386, (0.148 sec/step)
# step 5216 - loss = 2.470, (0.147 sec/step)
# step 5217 - loss = 2.507, (0.147 sec/step)
# step 5218 - loss = 2.495, (0.147 sec/step)
# step 5219 - loss = 2.564, (0.147 sec/step)
# step 5220 - loss = 2.561, (0.147 sec/step)
# step 5221 - loss = 2.495, (0.148 sec/step)
# step 5222 - loss = 2.434, (0.147 sec/step)
# step 5223 - loss = 2.314, (0.148 sec/step)
# step 5224 - loss = 2.418, (0.148 sec/step)
# step 5225 - loss = 2.370, (0.148 sec/step)
# step 5226 - loss = 2.439, (0.147 sec/step)
# step 5227 - loss = 2.406, (0.148 sec/step)
# step 5228 - loss = 2.199, (0.148 sec/step)
# step 5229 - loss = 2.443, (0.149 sec/step)
# step 5230 - loss = 2.434, (0.147 sec/step)
# step 5231 - loss = 2.278, (0.149 sec/step)
# step 5232 - loss = 1.968, (0.148 sec/step)
# step 5233 - loss = 2.372, (0.148 sec/step)
# step 5234 - loss = 2.377, (0.147 sec/step)
# step 5235 - loss = 2.446, (0.147 sec/step)
# step 5236 - loss = 2.380, (0.148 sec/step)
# step 5237 - loss = 2.422, (0.148 sec/step)
# step 5238 - loss = 2.372, (0.147 sec/step)
# step 5239 - loss = 2.386, (0.147 sec/step)
# step 5240 - loss = 2.454, (0.147 sec/step)
# step 5241 - loss = 2.476, (0.149 sec/step)
# step 5242 - loss = 2.499, (0.148 sec/step)
# step 5243 - loss = 2.498, (0.148 sec/step)
# step 5244 - loss = 2.649, (0.150 sec/step)
# step 5245 - loss = 2.647, (0.149 sec/step)
# step 5246 - loss = 2.487, (0.148 sec/step)
# step 5247 - loss = 2.572, (0.148 sec/step)
# step 5248 - loss = 2.530, (0.147 sec/step)
# step 5249 - loss = 2.333, (0.147 sec/step)
# step 5250 - loss = 2.647, (0.148 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5251 - loss = 2.600, (0.148 sec/step)
# step 5252 - loss = 2.357, (0.148 sec/step)
# step 5253 - loss = 2.464, (0.147 sec/step)
# step 5254 - loss = 2.578, (0.148 sec/step)
# step 5255 - loss = 2.423, (0.149 sec/step)
# step 5256 - loss = 2.437, (0.147 sec/step)
# step 5257 - loss = 2.572, (0.147 sec/step)
# step 5258 - loss = 2.413, (0.150 sec/step)
# step 5259 - loss = 2.298, (0.147 sec/step)
# step 5260 - loss = 2.578, (0.148 sec/step)
# step 5261 - loss = 2.384, (0.149 sec/step)
# step 5262 - loss = 2.194, (0.147 sec/step)
# step 5263 - loss = 2.607, (0.148 sec/step)
# step 5264 - loss = 2.381, (0.147 sec/step)
# step 5265 - loss = 2.575, (0.147 sec/step)
# step 5266 - loss = 2.467, (0.148 sec/step)
# step 5267 - loss = 2.445, (0.147 sec/step)
# step 5268 - loss = 2.344, (0.147 sec/step)
# step 5269 - loss = 2.706, (0.148 sec/step)
# step 5270 - loss = 2.468, (0.147 sec/step)
# step 5271 - loss = 2.417, (0.148 sec/step)
# step 5272 - loss = 2.399, (0.147 sec/step)
# step 5273 - loss = 2.406, (0.149 sec/step)
# step 5274 - loss = 2.627, (0.150 sec/step)
# step 5275 - loss = 2.521, (0.147 sec/step)
# step 5276 - loss = 2.594, (0.148 sec/step)
# step 5277 - loss = 2.718, (0.147 sec/step)
# step 5278 - loss = 2.524, (0.147 sec/step)
# step 5279 - loss = 2.364, (0.147 sec/step)
# step 5280 - loss = 2.794, (0.147 sec/step)
# step 5281 - loss = 2.665, (0.148 sec/step)
# step 5282 - loss = 2.508, (0.147 sec/step)
# step 5283 - loss = 2.636, (0.147 sec/step)
# step 5284 - loss = 2.498, (0.146 sec/step)
# step 5285 - loss = 2.612, (0.147 sec/step)
# step 5286 - loss = 2.424, (0.147 sec/step)
# step 5287 - loss = 2.735, (0.148 sec/step)
# step 5288 - loss = 2.480, (0.150 sec/step)
# step 5289 - loss = 2.272, (0.147 sec/step)
# step 5290 - loss = 2.570, (0.149 sec/step)
# step 5291 - loss = 2.501, (0.147 sec/step)
# step 5292 - loss = 2.618, (0.147 sec/step)
# step 5293 - loss = 2.503, (0.147 sec/step)
# step 5294 - loss = 2.333, (0.149 sec/step)
# step 5295 - loss = 2.545, (0.148 sec/step)
# step 5296 - loss = 2.545, (0.147 sec/step)
# step 5297 - loss = 2.578, (0.148 sec/step)
# step 5298 - loss = 2.425, (0.147 sec/step)
# step 5299 - loss = 2.485, (0.147 sec/step)
# step 5300 - loss = 2.576, (0.147 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5301 - loss = 2.606, (0.148 sec/step)
# step 5302 - loss = 2.452, (0.148 sec/step)
# step 5303 - loss = 2.544, (0.147 sec/step)
# step 5304 - loss = 2.573, (0.147 sec/step)
# step 5305 - loss = 2.766, (0.148 sec/step)
# step 5306 - loss = 2.430, (0.148 sec/step)
# step 5307 - loss = 2.341, (0.147 sec/step)
# step 5308 - loss = 2.537, (0.150 sec/step)
# step 5309 - loss = 2.685, (0.147 sec/step)
# step 5310 - loss = 2.434, (0.147 sec/step)
# step 5311 - loss = 2.609, (0.147 sec/step)
# step 5312 - loss = 2.384, (0.149 sec/step)
# step 5313 - loss = 2.801, (0.149 sec/step)
# step 5314 - loss = 2.609, (0.148 sec/step)
# step 5315 - loss = 2.523, (0.148 sec/step)
# step 5316 - loss = 2.646, (0.147 sec/step)
# step 5317 - loss = 2.502, (0.148 sec/step)
# step 5318 - loss = 2.541, (0.148 sec/step)
# step 5319 - loss = 2.475, (0.148 sec/step)
# step 5320 - loss = 2.903, (0.148 sec/step)
# step 5321 - loss = 2.685, (0.147 sec/step)
# step 5322 - loss = 2.712, (0.148 sec/step)
# step 5323 - loss = 2.635, (0.148 sec/step)
# step 5324 - loss = 2.562, (0.147 sec/step)
# step 5325 - loss = 2.684, (0.148 sec/step)
# step 5326 - loss = 2.697, (0.148 sec/step)
# step 5327 - loss = 2.570, (0.147 sec/step)
# step 5328 - loss = 2.449, (0.148 sec/step)
# step 5329 - loss = 2.567, (0.148 sec/step)
# step 5330 - loss = 2.692, (0.148 sec/step)
# step 5331 - loss = 2.460, (0.148 sec/step)
# step 5332 - loss = 2.429, (0.147 sec/step)
# step 5333 - loss = 2.483, (0.148 sec/step)
# step 5334 - loss = 2.523, (0.148 sec/step)
# step 5335 - loss = 2.593, (0.148 sec/step)
# step 5336 - loss = 2.553, (0.147 sec/step)
# step 5337 - loss = 2.238, (0.148 sec/step)
# step 5338 - loss = 2.379, (0.152 sec/step)
# step 5339 - loss = 2.670, (0.148 sec/step)
# step 5340 - loss = 2.261, (0.147 sec/step)
# step 5341 - loss = 2.523, (0.148 sec/step)
# step 5342 - loss = 2.806, (0.148 sec/step)
# step 5343 - loss = 2.645, (0.148 sec/step)
# step 5344 - loss = 2.606, (0.149 sec/step)
# step 5345 - loss = 2.500, (0.155 sec/step)
# step 5346 - loss = 2.635, (0.148 sec/step)
# step 5347 - loss = 2.612, (0.148 sec/step)
# step 5348 - loss = 2.577, (0.147 sec/step)
# step 5349 - loss = 2.638, (0.147 sec/step)
# step 5350 - loss = 2.655, (0.147 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5351 - loss = 2.699, (0.149 sec/step)
# step 5352 - loss = 2.618, (0.148 sec/step)
# step 5353 - loss = 2.467, (0.149 sec/step)
# step 5354 - loss = 2.443, (0.147 sec/step)
# step 5355 - loss = 2.148, (0.147 sec/step)
# step 5356 - loss = 2.588, (0.146 sec/step)
# step 5357 - loss = 2.571, (0.148 sec/step)
# step 5358 - loss = 2.388, (0.148 sec/step)
# step 5359 - loss = 2.625, (0.147 sec/step)
# step 5360 - loss = 2.490, (0.147 sec/step)
# step 5361 - loss = 2.262, (0.147 sec/step)
# step 5362 - loss = 2.449, (0.147 sec/step)
# step 5363 - loss = 2.363, (0.152 sec/step)
# step 5364 - loss = 2.481, (0.148 sec/step)
# step 5365 - loss = 2.564, (0.151 sec/step)
# step 5366 - loss = 2.246, (0.149 sec/step)
# step 5367 - loss = 2.526, (0.150 sec/step)
# step 5368 - loss = 2.450, (0.148 sec/step)
# step 5369 - loss = 2.408, (0.148 sec/step)
# step 5370 - loss = 2.409, (0.149 sec/step)
# step 5371 - loss = 2.486, (0.148 sec/step)
# step 5372 - loss = 2.405, (0.147 sec/step)
# step 5373 - loss = 2.379, (0.147 sec/step)
# step 5374 - loss = 2.680, (0.147 sec/step)
# step 5375 - loss = 2.259, (0.147 sec/step)
# step 5376 - loss = 2.479, (0.147 sec/step)
# step 5377 - loss = 2.334, (0.148 sec/step)
# step 5378 - loss = 2.367, (0.148 sec/step)
# step 5379 - loss = 2.461, (0.147 sec/step)
# step 5380 - loss = 2.345, (0.147 sec/step)
# step 5381 - loss = 2.421, (0.148 sec/step)
# step 5382 - loss = 2.481, (0.147 sec/step)
# step 5383 - loss = 2.339, (0.147 sec/step)
# step 5384 - loss = 2.337, (0.149 sec/step)
# step 5385 - loss = 2.440, (0.148 sec/step)
# step 5386 - loss = 2.447, (0.147 sec/step)
# step 5387 - loss = 2.281, (0.148 sec/step)
# step 5388 - loss = 2.398, (0.147 sec/step)
# step 5389 - loss = 2.547, (0.148 sec/step)
# step 5390 - loss = 2.324, (0.145 sec/step)
# step 5391 - loss = 2.534, (0.148 sec/step)
# step 5392 - loss = 1.941, (0.148 sec/step)
# step 5393 - loss = 2.445, (0.148 sec/step)
# step 5394 - loss = 2.281, (0.150 sec/step)
# step 5395 - loss = 2.383, (0.149 sec/step)
# step 5396 - loss = 2.420, (0.147 sec/step)
# step 5397 - loss = 2.182, (0.148 sec/step)
# step 5398 - loss = 2.201, (0.149 sec/step)
# step 5399 - loss = 2.337, (0.149 sec/step)
# step 5400 - loss = 2.434, (0.147 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5401 - loss = 2.319, (0.148 sec/step)
# step 5402 - loss = 2.426, (0.148 sec/step)
# step 5403 - loss = 2.396, (0.148 sec/step)
# step 5404 - loss = 2.148, (0.147 sec/step)
# step 5405 - loss = 2.288, (0.147 sec/step)
# step 5406 - loss = 2.258, (0.148 sec/step)
# step 5407 - loss = 2.397, (0.146 sec/step)
# step 5408 - loss = 2.418, (0.150 sec/step)
# step 5409 - loss = 2.523, (0.156 sec/step)
# step 5410 - loss = 2.474, (0.148 sec/step)
# step 5411 - loss = 2.303, (0.148 sec/step)
# step 5412 - loss = 2.394, (0.148 sec/step)
# step 5413 - loss = 2.433, (0.148 sec/step)
# step 5414 - loss = 2.425, (0.148 sec/step)
# step 5415 - loss = 2.524, (0.148 sec/step)
# step 5416 - loss = 2.435, (0.148 sec/step)
# step 5417 - loss = 2.327, (0.147 sec/step)
# step 5418 - loss = 2.322, (0.147 sec/step)
# step 5419 - loss = 2.365, (0.147 sec/step)
# step 5420 - loss = 2.838, (0.147 sec/step)
# step 5421 - loss = 2.474, (0.147 sec/step)
# step 5422 - loss = 2.350, (0.148 sec/step)
# step 5423 - loss = 2.399, (0.149 sec/step)
# step 5424 - loss = 2.453, (0.148 sec/step)
# step 5425 - loss = 2.618, (0.148 sec/step)
# step 5426 - loss = 2.559, (0.147 sec/step)
# step 5427 - loss = 2.227, (0.149 sec/step)
# step 5428 - loss = 2.552, (0.148 sec/step)
# step 5429 - loss = 2.602, (0.150 sec/step)
# step 5430 - loss = 2.502, (0.148 sec/step)
# step 5431 - loss = 2.419, (0.148 sec/step)
# step 5432 - loss = 2.450, (0.147 sec/step)
# step 5433 - loss = 2.534, (0.147 sec/step)
# step 5434 - loss = 2.437, (0.147 sec/step)
# step 5435 - loss = 2.600, (0.148 sec/step)
# step 5436 - loss = 2.737, (0.148 sec/step)
# step 5437 - loss = 2.650, (0.148 sec/step)
# step 5438 - loss = 2.645, (0.148 sec/step)
# step 5439 - loss = 2.738, (0.146 sec/step)
# step 5440 - loss = 2.389, (0.147 sec/step)
# step 5441 - loss = 2.647, (0.147 sec/step)
# step 5442 - loss = 2.430, (0.147 sec/step)
# step 5443 - loss = 2.620, (0.148 sec/step)
# step 5444 - loss = 2.538, (0.148 sec/step)
# step 5445 - loss = 2.539, (0.148 sec/step)
# step 5446 - loss = 2.499, (0.148 sec/step)
# step 5447 - loss = 2.646, (0.148 sec/step)
# step 5448 - loss = 2.600, (0.149 sec/step)
# step 5449 - loss = 2.563, (0.147 sec/step)
# step 5450 - loss = 2.194, (0.148 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5451 - loss = 2.473, (0.149 sec/step)
# step 5452 - loss = 2.754, (0.148 sec/step)
# step 5453 - loss = 2.563, (0.148 sec/step)
# step 5454 - loss = 2.527, (0.148 sec/step)
# step 5455 - loss = 2.440, (0.148 sec/step)
# step 5456 - loss = 2.218, (0.148 sec/step)
# step 5457 - loss = 2.735, (0.147 sec/step)
# step 5458 - loss = 2.425, (0.147 sec/step)
# step 5459 - loss = 2.339, (0.147 sec/step)
# step 5460 - loss = 2.308, (0.147 sec/step)
# step 5461 - loss = 2.360, (0.148 sec/step)
# step 5462 - loss = 2.777, (0.148 sec/step)
# step 5463 - loss = 2.470, (0.147 sec/step)
# step 5464 - loss = 2.390, (0.147 sec/step)
# step 5465 - loss = 2.763, (0.147 sec/step)
# step 5466 - loss = 2.520, (0.147 sec/step)
# step 5467 - loss = 2.110, (0.149 sec/step)
# step 5468 - loss = 2.437, (0.148 sec/step)
# step 5469 - loss = 2.176, (0.148 sec/step)
# step 5470 - loss = 2.765, (0.147 sec/step)
# step 5471 - loss = 2.625, (0.147 sec/step)
# step 5472 - loss = 2.373, (0.146 sec/step)
# step 5473 - loss = 2.331, (0.147 sec/step)
# step 5474 - loss = 2.497, (0.147 sec/step)
# step 5475 - loss = 2.431, (0.148 sec/step)
# step 5476 - loss = 2.710, (0.147 sec/step)
# step 5477 - loss = 2.631, (0.148 sec/step)
# step 5478 - loss = 2.475, (0.147 sec/step)
# step 5479 - loss = 2.542, (0.149 sec/step)
# step 5480 - loss = 2.358, (0.147 sec/step)
# step 5481 - loss = 2.618, (0.148 sec/step)
# step 5482 - loss = 2.666, (0.148 sec/step)
# step 5483 - loss = 2.789, (0.147 sec/step)
# step 5484 - loss = 2.851, (0.147 sec/step)
# step 5485 - loss = 2.912, (0.147 sec/step)
# step 5486 - loss = 3.043, (0.147 sec/step)
# step 5487 - loss = 2.848, (0.147 sec/step)
# step 5488 - loss = 3.004, (0.148 sec/step)
# step 5489 - loss = 3.001, (0.148 sec/step)
# step 5490 - loss = 2.800, (0.147 sec/step)
# step 5491 - loss = 2.757, (0.147 sec/step)
# step 5492 - loss = 2.758, (0.148 sec/step)
# step 5493 - loss = 2.820, (0.147 sec/step)
# step 5494 - loss = 2.566, (0.151 sec/step)
# step 5495 - loss = 2.754, (0.147 sec/step)
# step 5496 - loss = 2.727, (0.148 sec/step)
# step 5497 - loss = 2.575, (0.148 sec/step)
# step 5498 - loss = 2.702, (0.147 sec/step)
# step 5499 - loss = 2.798, (0.147 sec/step)
# step 5500 - loss = 2.638, (0.147 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5501 - loss = 2.552, (0.148 sec/step)
# step 5502 - loss = 2.572, (0.148 sec/step)
# step 5503 - loss = 2.720, (0.147 sec/step)
# step 5504 - loss = 2.716, (0.146 sec/step)
# step 5505 - loss = 2.368, (0.147 sec/step)
# step 5506 - loss = 2.743, (0.149 sec/step)
# step 5507 - loss = 3.187, (0.148 sec/step)
# step 5508 - loss = 2.693, (0.147 sec/step)
# step 5509 - loss = 2.766, (0.148 sec/step)
# step 5510 - loss = 2.704, (0.147 sec/step)
# step 5511 - loss = 2.598, (0.150 sec/step)
# step 5512 - loss = 2.818, (0.148 sec/step)
# step 5513 - loss = 2.803, (0.148 sec/step)
# step 5514 - loss = 2.717, (0.149 sec/step)
# step 5515 - loss = 2.765, (0.147 sec/step)
# step 5516 - loss = 2.713, (0.147 sec/step)
# step 5517 - loss = 2.726, (0.147 sec/step)
# step 5518 - loss = 2.672, (0.147 sec/step)
# step 5519 - loss = 2.680, (0.147 sec/step)
# step 5520 - loss = 2.564, (0.147 sec/step)
# step 5521 - loss = 2.635, (0.147 sec/step)
# step 5522 - loss = 2.731, (0.147 sec/step)
# step 5523 - loss = 2.639, (0.148 sec/step)
# step 5524 - loss = 2.674, (0.147 sec/step)
# step 5525 - loss = 2.552, (0.147 sec/step)
# step 5526 - loss = 2.612, (0.147 sec/step)
# step 5527 - loss = 2.603, (0.147 sec/step)
# step 5528 - loss = 2.530, (0.147 sec/step)
# step 5529 - loss = 2.717, (0.148 sec/step)
# step 5530 - loss = 2.501, (0.148 sec/step)
# step 5531 - loss = 2.638, (0.148 sec/step)
# step 5532 - loss = 2.329, (0.147 sec/step)
# step 5533 - loss = 2.559, (0.148 sec/step)
# step 5534 - loss = 2.662, (0.148 sec/step)
# files length: 1
# step 5535 - loss = 2.461, (0.199 sec/step)
# step 5536 - loss = 2.738, (0.158 sec/step)
# step 5537 - loss = 2.639, (0.152 sec/step)
# step 5538 - loss = 2.667, (0.232 sec/step)
# step 5539 - loss = 2.351, (0.167 sec/step)
# step 5540 - loss = 2.519, (0.168 sec/step)
# step 5541 - loss = 2.280, (0.150 sec/step)
# step 5542 - loss = 2.502, (0.148 sec/step)
# step 5543 - loss = 2.390, (0.149 sec/step)
# step 5544 - loss = 2.373, (0.148 sec/step)
# step 5545 - loss = 2.528, (0.148 sec/step)
# step 5546 - loss = 2.523, (0.148 sec/step)
# step 5547 - loss = 2.684, (0.149 sec/step)
# step 5548 - loss = 2.376, (0.148 sec/step)
# step 5549 - loss = 2.451, (0.148 sec/step)
# step 5550 - loss = 2.463, (0.148 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5551 - loss = 2.483, (0.150 sec/step)
# step 5552 - loss = 2.374, (0.149 sec/step)
# step 5553 - loss = 2.568, (0.148 sec/step)
# step 5554 - loss = 2.672, (0.149 sec/step)
# step 5555 - loss = 2.434, (0.148 sec/step)
# step 5556 - loss = 2.415, (0.150 sec/step)
# step 5557 - loss = 2.592, (0.148 sec/step)
# step 5558 - loss = 2.541, (0.148 sec/step)
# step 5559 - loss = 2.332, (0.156 sec/step)
# step 5560 - loss = 2.569, (0.148 sec/step)
# step 5561 - loss = 2.496, (0.149 sec/step)
# step 5562 - loss = 2.221, (0.149 sec/step)
# step 5563 - loss = 2.479, (0.149 sec/step)
# step 5564 - loss = 2.341, (0.148 sec/step)
# step 5565 - loss = 2.297, (0.154 sec/step)
# step 5566 - loss = 2.413, (0.149 sec/step)
# step 5567 - loss = 2.647, (0.083 sec/step)
# step 5568 - loss = 2.833, (12.648 sec/step)
# step 5569 - loss = 2.448, (0.148 sec/step)
# step 5570 - loss = 2.537, (0.149 sec/step)
# step 5571 - loss = 2.376, (0.148 sec/step)
# step 5572 - loss = 2.546, (0.148 sec/step)
# step 5573 - loss = 2.628, (0.147 sec/step)
# step 5574 - loss = 2.464, (0.147 sec/step)
# step 5575 - loss = 2.415, (0.148 sec/step)
# step 5576 - loss = 2.599, (0.147 sec/step)
# step 5577 - loss = 2.419, (0.147 sec/step)
# step 5578 - loss = 2.548, (0.148 sec/step)
# step 5579 - loss = 2.586, (0.147 sec/step)
# step 5580 - loss = 2.371, (0.149 sec/step)
# step 5581 - loss = 2.550, (0.147 sec/step)
# step 5582 - loss = 2.312, (0.147 sec/step)
# step 5583 - loss = 2.477, (0.148 sec/step)
# step 5584 - loss = 2.608, (0.147 sec/step)
# step 5585 - loss = 2.510, (0.148 sec/step)
# step 5586 - loss = 2.528, (0.147 sec/step)
# step 5587 - loss = 2.510, (0.147 sec/step)
# step 5588 - loss = 2.523, (0.147 sec/step)
# step 5589 - loss = 2.558, (0.147 sec/step)
# step 5590 - loss = 2.521, (0.147 sec/step)
# step 5591 - loss = 2.204, (0.149 sec/step)
# step 5592 - loss = 2.444, (0.150 sec/step)
# step 5593 - loss = 2.694, (0.148 sec/step)
# step 5594 - loss = 2.403, (0.147 sec/step)
# step 5595 - loss = 2.427, (0.147 sec/step)
# step 5596 - loss = 2.335, (0.147 sec/step)
# step 5597 - loss = 2.511, (0.147 sec/step)
# step 5598 - loss = 2.438, (0.148 sec/step)
# step 5599 - loss = 2.394, (0.148 sec/step)
# step 5600 - loss = 2.424, (0.147 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5601 - loss = 2.672, (0.149 sec/step)
# step 5602 - loss = 2.458, (0.151 sec/step)
# step 5603 - loss = 2.321, (0.151 sec/step)
# step 5604 - loss = 2.534, (0.148 sec/step)
# step 5605 - loss = 2.449, (0.148 sec/step)
# step 5606 - loss = 2.637, (0.148 sec/step)
# step 5607 - loss = 2.558, (0.148 sec/step)
# step 5608 - loss = 2.462, (0.148 sec/step)
# step 5609 - loss = 2.349, (0.148 sec/step)
# step 5610 - loss = 2.474, (0.149 sec/step)
# step 5611 - loss = 2.454, (0.148 sec/step)
# step 5612 - loss = 2.548, (0.149 sec/step)
# step 5613 - loss = 2.442, (0.147 sec/step)
# step 5614 - loss = 2.637, (0.147 sec/step)
# step 5615 - loss = 2.497, (0.148 sec/step)
# step 5616 - loss = 2.573, (0.150 sec/step)
# step 5617 - loss = 2.378, (0.148 sec/step)
# step 5618 - loss = 2.582, (0.148 sec/step)
# step 5619 - loss = 2.326, (0.148 sec/step)
# step 5620 - loss = 2.392, (0.148 sec/step)
# step 5621 - loss = 2.409, (0.149 sec/step)
# step 5622 - loss = 2.526, (0.149 sec/step)
# step 5623 - loss = 2.282, (0.149 sec/step)
# step 5624 - loss = 2.430, (0.147 sec/step)
# step 5625 - loss = 2.533, (0.148 sec/step)
# step 5626 - loss = 2.548, (0.148 sec/step)
# step 5627 - loss = 2.468, (0.148 sec/step)
# step 5628 - loss = 2.313, (0.150 sec/step)
# step 5629 - loss = 2.475, (0.150 sec/step)
# step 5630 - loss = 2.504, (0.149 sec/step)
# step 5631 - loss = 2.395, (0.152 sec/step)
# step 5632 - loss = 2.232, (0.148 sec/step)
# step 5633 - loss = 2.561, (0.147 sec/step)
# step 5634 - loss = 2.605, (0.148 sec/step)
# step 5635 - loss = 2.515, (0.148 sec/step)
# step 5636 - loss = 2.431, (0.148 sec/step)
# step 5637 - loss = 2.560, (0.149 sec/step)
# step 5638 - loss = 2.418, (0.149 sec/step)
# step 5639 - loss = 2.540, (0.148 sec/step)
# step 5640 - loss = 2.588, (0.148 sec/step)
# step 5641 - loss = 2.296, (0.148 sec/step)
# step 5642 - loss = 2.631, (0.148 sec/step)
# step 5643 - loss = 2.203, (0.148 sec/step)
# step 5644 - loss = 2.372, (0.150 sec/step)
# step 5645 - loss = 2.543, (0.148 sec/step)
# step 5646 - loss = 2.687, (0.148 sec/step)
# step 5647 - loss = 2.714, (0.148 sec/step)
# step 5648 - loss = 2.658, (0.148 sec/step)
# step 5649 - loss = 2.655, (0.148 sec/step)
# step 5650 - loss = 2.727, (0.147 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5651 - loss = 2.478, (0.150 sec/step)
# step 5652 - loss = 2.625, (0.148 sec/step)
# step 5653 - loss = 2.613, (0.148 sec/step)
# step 5654 - loss = 2.511, (0.148 sec/step)
# step 5655 - loss = 2.718, (0.148 sec/step)
# step 5656 - loss = 2.664, (0.148 sec/step)
# step 5657 - loss = 2.569, (0.148 sec/step)
# step 5658 - loss = 2.453, (0.148 sec/step)
# step 5659 - loss = 2.687, (0.148 sec/step)
# step 5660 - loss = 2.666, (0.148 sec/step)
# step 5661 - loss = 2.740, (0.150 sec/step)
# step 5662 - loss = 2.384, (0.149 sec/step)
# step 5663 - loss = 2.470, (0.148 sec/step)
# step 5664 - loss = 2.394, (0.147 sec/step)
# step 5665 - loss = 2.525, (0.148 sec/step)
# step 5666 - loss = 2.502, (0.148 sec/step)
# step 5667 - loss = 2.668, (0.148 sec/step)
# step 5668 - loss = 2.512, (0.149 sec/step)
# step 5669 - loss = 2.435, (0.147 sec/step)
# step 5670 - loss = 2.628, (0.148 sec/step)
# step 5671 - loss = 2.430, (0.147 sec/step)
# step 5672 - loss = 2.445, (0.148 sec/step)
# step 5673 - loss = 2.503, (0.149 sec/step)
# step 5674 - loss = 2.679, (0.150 sec/step)
# step 5675 - loss = 2.433, (0.148 sec/step)
# step 5676 - loss = 2.233, (0.151 sec/step)
# step 5677 - loss = 2.528, (0.148 sec/step)
# step 5678 - loss = 2.367, (0.147 sec/step)
# step 5679 - loss = 2.331, (0.149 sec/step)
# step 5680 - loss = 2.472, (0.149 sec/step)
# step 5681 - loss = 2.362, (0.148 sec/step)
# step 5682 - loss = 2.295, (0.149 sec/step)
# step 5683 - loss = 2.521, (0.151 sec/step)
# step 5684 - loss = 2.443, (0.148 sec/step)
# step 5685 - loss = 2.367, (0.149 sec/step)
# step 5686 - loss = 2.506, (0.148 sec/step)
# step 5687 - loss = 2.597, (0.147 sec/step)
# step 5688 - loss = 2.465, (0.148 sec/step)
# step 5689 - loss = 2.435, (0.149 sec/step)
# step 5690 - loss = 2.540, (0.147 sec/step)
# step 5691 - loss = 2.455, (0.147 sec/step)
# step 5692 - loss = 2.365, (0.148 sec/step)
# step 5693 - loss = 2.507, (0.148 sec/step)
# step 5694 - loss = 2.517, (0.148 sec/step)
# step 5695 - loss = 2.474, (0.147 sec/step)
# step 5696 - loss = 2.359, (0.148 sec/step)
# step 5697 - loss = 2.286, (0.147 sec/step)
# step 5698 - loss = 2.450, (0.148 sec/step)
# step 5699 - loss = 2.624, (0.147 sec/step)
# step 5700 - loss = 2.595, (0.147 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5701 - loss = 2.209, (0.149 sec/step)
# step 5702 - loss = 2.421, (0.147 sec/step)
# step 5703 - loss = 2.595, (0.148 sec/step)
# step 5704 - loss = 2.397, (0.147 sec/step)
# step 5705 - loss = 2.403, (0.148 sec/step)
# step 5706 - loss = 2.226, (0.148 sec/step)
# step 5707 - loss = 2.552, (0.148 sec/step)
# step 5708 - loss = 2.417, (0.149 sec/step)
# step 5709 - loss = 2.433, (0.147 sec/step)
# step 5710 - loss = 2.446, (0.148 sec/step)
# step 5711 - loss = 2.555, (0.148 sec/step)
# step 5712 - loss = 2.618, (0.148 sec/step)
# step 5713 - loss = 2.511, (0.148 sec/step)
# step 5714 - loss = 2.562, (0.147 sec/step)
# step 5715 - loss = 2.520, (0.148 sec/step)
# step 5716 - loss = 2.547, (0.147 sec/step)
# step 5717 - loss = 2.352, (0.148 sec/step)
# step 5718 - loss = 2.506, (0.148 sec/step)
# step 5719 - loss = 2.433, (0.148 sec/step)
# step 5720 - loss = 2.498, (0.148 sec/step)
# step 5721 - loss = 2.036, (0.148 sec/step)
# step 5722 - loss = 2.615, (0.148 sec/step)
# step 5723 - loss = 2.573, (0.148 sec/step)
# step 5724 - loss = 2.562, (0.147 sec/step)
# step 5725 - loss = 2.627, (0.148 sec/step)
# step 5726 - loss = 2.635, (0.148 sec/step)
# step 5727 - loss = 2.308, (0.148 sec/step)
# step 5728 - loss = 2.353, (0.147 sec/step)
# step 5729 - loss = 2.589, (0.147 sec/step)
# step 5730 - loss = 2.340, (0.148 sec/step)
# step 5731 - loss = 2.381, (0.147 sec/step)
# step 5732 - loss = 2.715, (0.148 sec/step)
# step 5733 - loss = 2.351, (0.149 sec/step)
# step 5734 - loss = 2.550, (0.149 sec/step)
# step 5735 - loss = 2.739, (0.149 sec/step)
# step 5736 - loss = 2.564, (0.149 sec/step)
# step 5737 - loss = 2.494, (0.147 sec/step)
# step 5738 - loss = 2.373, (0.147 sec/step)
# step 5739 - loss = 2.330, (0.148 sec/step)
# step 5740 - loss = 2.045, (0.148 sec/step)
# step 5741 - loss = 2.578, (0.149 sec/step)
# ...
# step 8965 - loss = 2.350, (0.148 sec/step)
# step 8966 - loss = 2.507, (0.148 sec/step)
# step 8967 - loss = 2.344, (0.148 sec/step)
# step 8968 - loss = 2.347, (0.148 sec/step)
# step 8969 - loss = 2.463, (0.147 sec/step)
# step 8970 - loss = 2.308, (0.147 sec/step)
# step 8971 - loss = 2.229, (0.147 sec/step)
# step 8972 - loss = 2.559, (0.147 sec/step)
# step 8973 - loss = 2.324, (0.147 sec/step)
# step 8974 - loss = 2.141, (0.148 sec/step)
# step 8975 - loss = 2.663, (0.149 sec/step)
# step 8976 - loss = 2.285, (0.147 sec/step)
# step 8977 - loss = 2.497, (0.149 sec/step)
# step 8978 - loss = 2.446, (0.148 sec/step)
# step 8979 - loss = 2.297, (0.147 sec/step)
# step 8980 - loss = 2.314, (0.149 sec/step)
# step 8981 - loss = 2.747, (0.148 sec/step)
# step 8982 - loss = 2.334, (0.151 sec/step)
# step 8983 - loss = 2.433, (0.147 sec/step)
# step 8984 - loss = 2.337, (0.149 sec/step)
# step 8985 - loss = 2.368, (0.147 sec/step)
# step 8986 - loss = 2.506, (0.147 sec/step)
# step 8987 - loss = 2.452, (0.149 sec/step)
# step 8988 - loss = 2.493, (0.148 sec/step)
# step 8989 - loss = 2.596, (0.148 sec/step)
# step 8990 - loss = 2.424, (0.148 sec/step)
# step 8991 - loss = 2.296, (0.148 sec/step)
# step 8992 - loss = 2.671, (0.147 sec/step)
# step 8993 - loss = 2.578, (0.148 sec/step)
# step 8994 - loss = 2.408, (0.148 sec/step)
# step 8995 - loss = 2.592, (0.147 sec/step)
# step 8996 - loss = 2.420, (0.151 sec/step)
# step 8997 - loss = 2.441, (0.148 sec/step)
# step 8998 - loss = 2.420, (0.148 sec/step)
# step 8999 - loss = 2.636, (0.148 sec/step)
# step 9000 - loss = 2.401, (0.147 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 9001 - loss = 2.204, (0.149 sec/step)
# step 9002 - loss = 2.511, (0.148 sec/step)
# step 9003 - loss = 2.409, (0.148 sec/step)
# step 9004 - loss = 2.522, (0.147 sec/step)
# step 9005 - loss = 2.374, (0.148 sec/step)
# step 9006 - loss = 2.221, (0.147 sec/step)
# step 9007 - loss = 2.373, (0.148 sec/step)
# step 9008 - loss = 2.410, (0.148 sec/step)
# step 9009 - loss = 2.491, (0.153 sec/step)
# step 9010 - loss = 2.160, (0.149 sec/step)
# step 9011 - loss = 2.300, (0.148 sec/step)
# step 9012 - loss = 2.489, (0.148 sec/step)
# step 9013 - loss = 2.354, (0.149 sec/step)
# step 9014 - loss = 2.289, (0.148 sec/step)
# step 9015 - loss = 2.391, (0.148 sec/step)
# step 9016 - loss = 2.372, (0.148 sec/step)
# step 9017 - loss = 2.644, (0.147 sec/step)
# step 9018 - loss = 2.319, (0.148 sec/step)
# step 9019 - loss = 2.188, (0.147 sec/step)
# step 9020 - loss = 2.493, (0.148 sec/step)
# step 9021 - loss = 2.510, (0.149 sec/step)
# step 9022 - loss = 2.209, (0.147 sec/step)
# step 9023 - loss = 2.446, (0.148 sec/step)
# step 9024 - loss = 2.145, (0.150 sec/step)
# step 9025 - loss = 2.604, (0.148 sec/step)
# step 9026 - loss = 2.406, (0.152 sec/step)
# step 9027 - loss = 2.277, (0.150 sec/step)
# step 9028 - loss = 2.478, (0.148 sec/step)
# step 9029 - loss = 2.174, (0.147 sec/step)
# step 9030 - loss = 2.400, (0.147 sec/step)
# step 9031 - loss = 2.254, (0.147 sec/step)
# step 9032 - loss = 2.526, (0.147 sec/step)
# step 9033 - loss = 2.457, (0.147 sec/step)
# step 9034 - loss = 2.512, (0.147 sec/step)
# step 9035 - loss = 2.451, (0.147 sec/step)
# step 9036 - loss = 2.348, (0.147 sec/step)
# step 9037 - loss = 2.498, (0.147 sec/step)
# step 9038 - loss = 2.517, (0.147 sec/step)
# step 9039 - loss = 2.409, (0.148 sec/step)
# step 9040 - loss = 2.328, (0.147 sec/step)
# step 9041 - loss = 2.405, (0.150 sec/step)
# step 9042 - loss = 2.493, (0.147 sec/step)
# step 9043 - loss = 2.321, (0.147 sec/step)
# step 9044 - loss = 2.250, (0.147 sec/step)
# step 9045 - loss = 2.412, (0.147 sec/step)
# step 9046 - loss = 2.445, (0.147 sec/step)
# step 9047 - loss = 2.418, (0.147 sec/step)
# step 9048 - loss = 2.398, (0.148 sec/step)
# step 9049 - loss = 2.100, (0.147 sec/step)
# step 9050 - loss = 2.249, (0.151 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 9051 - loss = 2.489, (0.148 sec/step)
# step 9052 - loss = 2.083, (0.148 sec/step)
# step 9053 - loss = 2.340, (0.148 sec/step)
# step 9054 - loss = 2.609, (0.147 sec/step)
# step 9055 - loss = 2.394, (0.147 sec/step)
# step 9056 - loss = 2.461, (0.148 sec/step)
# step 9057 - loss = 2.333, (0.148 sec/step)
# step 9058 - loss = 2.474, (0.149 sec/step)
# step 9059 - loss = 2.435, (0.151 sec/step)
# step 9060 - loss = 2.452, (0.147 sec/step)
# step 9061 - loss = 2.459, (0.148 sec/step)
# step 9062 - loss = 2.484, (0.147 sec/step)
# step 9063 - loss = 2.559, (0.147 sec/step)
# step 9064 - loss = 2.501, (0.147 sec/step)
# step 9065 - loss = 2.350, (0.148 sec/step)
# step 9066 - loss = 2.319, (0.147 sec/step)
# step 9067 - loss = 2.084, (0.147 sec/step)
# step 9068 - loss = 2.377, (0.147 sec/step)
# step 9069 - loss = 2.455, (0.147 sec/step)
# step 9070 - loss = 2.292, (0.148 sec/step)
# step 9071 - loss = 2.481, (0.148 sec/step)
# step 9072 - loss = 2.379, (0.150 sec/step)
# step 9073 - loss = 2.169, (0.148 sec/step)
# step 9074 - loss = 2.365, (0.150 sec/step)
# step 9075 - loss = 2.282, (0.147 sec/step)
# step 9076 - loss = 2.380, (0.149 sec/step)
# step 9077 - loss = 2.442, (0.149 sec/step)
# step 9078 - loss = 2.175, (0.149 sec/step)
# step 9079 - loss = 2.416, (0.149 sec/step)
# step 9080 - loss = 2.354, (0.148 sec/step)
# step 9081 - loss = 2.336, (0.150 sec/step)
# step 9082 - loss = 2.291, (0.147 sec/step)
# step 9083 - loss = 2.421, (0.147 sec/step)
# step 9084 - loss = 2.299, (0.147 sec/step)
# step 9085 - loss = 2.304, (0.148 sec/step)
# step 9086 - loss = 2.541, (0.147 sec/step)
# step 9087 - loss = 2.149, (0.147 sec/step)
# step 9088 - loss = 2.389, (0.147 sec/step)
# step 9089 - loss = 2.265, (0.149 sec/step)
# step 9090 - loss = 2.266, (0.148 sec/step)
# step 9091 - loss = 2.343, (0.148 sec/step)
# step 9092 - loss = 2.240, (0.147 sec/step)
# step 9093 - loss = 2.302, (0.148 sec/step)
# step 9094 - loss = 2.378, (0.148 sec/step)
# step 9095 - loss = 2.189, (0.147 sec/step)
# step 9096 - loss = 2.234, (0.147 sec/step)
# step 9097 - loss = 2.351, (0.148 sec/step)
# step 9098 - loss = 2.360, (0.148 sec/step)
# step 9099 - loss = 2.196, (0.147 sec/step)
# step 9100 - loss = 2.258, (0.148 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 9101 - loss = 2.424, (0.149 sec/step)
# step 9102 - loss = 2.241, (0.148 sec/step)
# step 9103 - loss = 2.382, (0.148 sec/step)
# step 9104 - loss = 1.845, (0.148 sec/step)
# step 9105 - loss = 2.324, (0.148 sec/step)
# step 9106 - loss = 2.163, (0.149 sec/step)
# step 9107 - loss = 2.304, (0.148 sec/step)
# step 9108 - loss = 2.346, (0.149 sec/step)
# step 9109 - loss = 2.112, (0.149 sec/step)
# step 9110 - loss = 2.114, (0.148 sec/step)
# step 9111 - loss = 2.240, (0.148 sec/step)
# step 9112 - loss = 2.304, (0.147 sec/step)
# step 9113 - loss = 2.192, (0.148 sec/step)
# step 9114 - loss = 2.340, (0.147 sec/step)
# step 9115 - loss = 2.289, (0.147 sec/step)
# step 9116 - loss = 2.042, (0.147 sec/step)
# step 9117 - loss = 2.225, (0.148 sec/step)
# step 9118 - loss = 2.167, (0.147 sec/step)
# step 9119 - loss = 2.304, (0.148 sec/step)
# step 9120 - loss = 2.332, (0.148 sec/step)
# step 9121 - loss = 2.375, (0.147 sec/step)
# step 9122 - loss = 2.376, (0.148 sec/step)
# step 9123 - loss = 2.242, (0.147 sec/step)
# step 9124 - loss = 2.304, (0.152 sec/step)
# step 9125 - loss = 2.309, (0.148 sec/step)
# step 9126 - loss = 2.293, (0.148 sec/step)
# step 9127 - loss = 2.384, (0.148 sec/step)
# step 9128 - loss = 2.317, (0.148 sec/step)
# step 9129 - loss = 2.258, (0.148 sec/step)
# step 9130 - loss = 2.267, (0.147 sec/step)
# step 9131 - loss = 2.256, (0.147 sec/step)
# step 9132 - loss = 2.641, (0.150 sec/step)
# step 9133 - loss = 2.380, (0.148 sec/step)
# step 9134 - loss = 2.258, (0.147 sec/step)
# step 9135 - loss = 2.321, (0.148 sec/step)
# step 9136 - loss = 2.347, (0.148 sec/step)
# step 9137 - loss = 2.486, (0.149 sec/step)
# step 9138 - loss = 2.471, (0.147 sec/step)
# step 9139 - loss = 2.124, (0.148 sec/step)
# step 9140 - loss = 2.392, (0.149 sec/step)
# step 9141 - loss = 2.446, (0.147 sec/step)
# step 9142 - loss = 2.428, (0.148 sec/step)
# step 9143 - loss = 2.217, (0.148 sec/step)
# step 9144 - loss = 2.306, (0.148 sec/step)
# step 9145 - loss = 2.389, (0.149 sec/step)
# step 9146 - loss = 2.287, (0.148 sec/step)
# step 9147 - loss = 2.464, (0.147 sec/step)
# step 9148 - loss = 2.537, (0.147 sec/step)
# step 9149 - loss = 2.424, (0.147 sec/step)
# step 9150 - loss = 2.488, (0.147 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 9151 - loss = 2.558, (0.149 sec/step)
# step 9152 - loss = 2.282, (0.147 sec/step)
# step 9153 - loss = 2.529, (0.148 sec/step)
# step 9154 - loss = 2.308, (0.147 sec/step)
# step 9155 - loss = 2.495, (0.149 sec/step)
# step 9156 - loss = 2.345, (0.147 sec/step)
# step 9157 - loss = 2.461, (0.147 sec/step)
# step 9158 - loss = 2.388, (0.148 sec/step)
# step 9159 - loss = 2.541, (0.148 sec/step)
# step 9160 - loss = 2.455, (0.147 sec/step)
# step 9161 - loss = 2.414, (0.148 sec/step)
# step 9162 - loss = 2.108, (0.152 sec/step)
# step 9163 - loss = 2.365, (0.151 sec/step)
# step 9164 - loss = 2.598, (0.150 sec/step)
# step 9165 - loss = 2.396, (0.148 sec/step)
# step 9166 - loss = 2.429, (0.147 sec/step)
# step 9167 - loss = 2.308, (0.148 sec/step)
# step 9168 - loss = 2.137, (0.147 sec/step)
# step 9169 - loss = 2.573, (0.148 sec/step)
# step 9170 - loss = 2.321, (0.152 sec/step)
# step 9171 - loss = 2.268, (0.147 sec/step)
# step 9172 - loss = 2.244, (0.148 sec/step)
# step 9173 - loss = 2.309, (0.147 sec/step)
# step 9174 - loss = 2.608, (0.147 sec/step)
# step 9175 - loss = 2.429, (0.148 sec/step)
# step 9176 - loss = 2.290, (0.147 sec/step)
# step 9177 - loss = 2.606, (0.147 sec/step)
# step 9178 - loss = 2.476, (0.148 sec/step)
# step 9179 - loss = 2.071, (0.148 sec/step)
# step 9180 - loss = 2.401, (0.147 sec/step)
# step 9181 - loss = 2.119, (0.148 sec/step)
# step 9182 - loss = 2.663, (0.148 sec/step)
# step 9183 - loss = 2.495, (0.148 sec/step)
# step 9184 - loss = 2.272, (0.148 sec/step)
# step 9185 - loss = 2.272, (0.149 sec/step)
# step 9186 - loss = 2.373, (0.148 sec/step)
# step 9187 - loss = 2.310, (0.148 sec/step)
# step 9188 - loss = 2.592, (0.148 sec/step)
# step 9189 - loss = 2.520, (0.147 sec/step)
# step 9190 - loss = 2.358, (0.148 sec/step)
# step 9191 - loss = 2.428, (0.147 sec/step)
# step 9192 - loss = 2.190, (0.147 sec/step)
# step 9193 - loss = 2.529, (0.147 sec/step)
# step 9194 - loss = 2.511, (0.147 sec/step)
# step 9195 - loss = 2.557, (0.147 sec/step)
# step 9196 - loss = 2.500, (0.147 sec/step)
# step 9197 - loss = 2.548, (0.148 sec/step)
# step 9198 - loss = 2.530, (0.148 sec/step)
# step 9199 - loss = 2.401, (0.147 sec/step)
# step 9200 - loss = 2.489, (0.148 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 9201 - loss = 2.536, (0.149 sec/step)
# step 9202 - loss = 2.355, (0.148 sec/step)
# step 9203 - loss = 2.424, (0.148 sec/step)
# step 9204 - loss = 2.336, (0.147 sec/step)
# step 9205 - loss = 2.493, (0.147 sec/step)
# step 9206 - loss = 2.210, (0.148 sec/step)
# step 9207 - loss = 2.339, (0.150 sec/step)
# step 9208 - loss = 2.283, (0.147 sec/step)
# step 9209 - loss = 2.269, (0.150 sec/step)
# step 9210 - loss = 2.465, (0.148 sec/step)
# step 9211 - loss = 2.476, (0.148 sec/step)
# step 9212 - loss = 2.360, (0.147 sec/step)
# step 9213 - loss = 2.279, (0.147 sec/step)
# step 9214 - loss = 2.274, (0.147 sec/step)
# step 9215 - loss = 2.454, (0.149 sec/step)
# step 9216 - loss = 2.418, (0.147 sec/step)
# step 9217 - loss = 2.088, (0.147 sec/step)
# step 9218 - loss = 2.480, (0.147 sec/step)
# step 9219 - loss = 2.223, (0.147 sec/step)
# step 9220 - loss = 2.443, (0.148 sec/step)
# step 9221 - loss = 2.280, (0.148 sec/step)
# step 9222 - loss = 2.436, (0.147 sec/step)
# step 9223 - loss = 2.139, (0.149 sec/step)
# step 9224 - loss = 2.420, (0.147 sec/step)
# step 9225 - loss = 2.306, (0.147 sec/step)
# step 9226 - loss = 2.264, (0.147 sec/step)
# step 9227 - loss = 2.242, (0.149 sec/step)
# step 9228 - loss = 2.325, (0.148 sec/step)
# step 9229 - loss = 2.420, (0.148 sec/step)
# step 9230 - loss = 2.430, (0.148 sec/step)
# step 9231 - loss = 2.386, (0.147 sec/step)
# step 9232 - loss = 2.158, (0.147 sec/step)
# step 9233 - loss = 2.344, (0.148 sec/step)
# step 9234 - loss = 2.444, (0.147 sec/step)
# step 9235 - loss = 2.336, (0.148 sec/step)
# step 9236 - loss = 2.378, (0.147 sec/step)
# step 9237 - loss = 2.219, (0.151 sec/step)
# step 9238 - loss = 2.341, (0.147 sec/step)
# step 9239 - loss = 2.348, (0.147 sec/step)
# step 9240 - loss = 2.286, (0.147 sec/step)
# step 9241 - loss = 2.482, (0.147 sec/step)
# step 9242 - loss = 2.248, (0.148 sec/step)
# step 9243 - loss = 2.425, (0.146 sec/step)
# step 9244 - loss = 2.110, (0.148 sec/step)
# step 9245 - loss = 2.346, (0.147 sec/step)
# step 9246 - loss = 2.417, (0.147 sec/step)
# files length: 1
# step 9247 - loss = 2.284, (0.178 sec/step)
# step 9248 - loss = 2.457, (0.180 sec/step)
# step 9249 - loss = 2.426, (0.153 sec/step)
# Storing checkpoint to ./logdir/train/2020-07-02T17-40-36 ...WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.

# %%
# !cd gdrive/My\ Drive/tensorflow-wavenet-new && python generate.py --wav_out_path=generated_short.wav --save_every 4000 --samples=16000 logdir/train/2020-07-02T17-40-36/model.ckpt-9249
# Out:
# 2020-07-02 18:51:51.117222: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2020-07-02 18:51:52.475497: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-02 18:51:52.477953: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-02 18:51:52.478516: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-07-02 18:51:52.478556: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-02 18:51:52.480494: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-07-02 18:51:52.493341: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-07-02 18:51:52.493800: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-07-02 18:51:52.502951: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-07-02 18:51:52.503870: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-07-02 18:51:52.519625: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-07-02 18:51:52.519753: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-02 18:51:52.520362: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-02 18:51:52.520860: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-07-02 18:51:52.526136: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2020-07-02 18:51:52.526338: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x6f20a80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-02 18:51:52.526367: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-07-02 18:51:52.614423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-02 18:51:52.615156: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x6f20c40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-07-02 18:51:52.615187: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-07-02 18:51:52.615411: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-02 18:51:52.615974: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-07-02 18:51:52.616040: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-02 18:51:52.616080: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-07-02 18:51:52.616104: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-07-02 18:51:52.616126: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-07-02 18:51:52.616146: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-07-02 18:51:52.616166: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-07-02 18:51:52.616187: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-07-02 18:51:52.616260: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-02 18:51:52.616792: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-02 18:51:52.617285: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-07-02 18:51:52.617359: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-02 18:51:53.110849: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-07-02 18:51:53.110910: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-07-02 18:51:53.110922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-07-02 18:51:53.111180: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-02 18:51:53.111783: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-02 18:51:53.112313: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-07-02 18:51:53.112368: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14651 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /content/gdrive/My Drive/tensorflow-wavenet-new/wavenet/model.py:27: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Restoring model from logdir/train/2020-07-02T17-40-36/model.ckpt-9249
# 2020-07-02 18:51:57.261846: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# Updated wav file at generated_short.wav
# Updated wav file at generated_short.wav
# Updated wav file at generated_short.wav
# Updated wav file at generated_short.wav
#
# Updated wav file at generated_short.wav
# Finished generating. The result can be viewed in TensorBoard.

# %%
##makes code tf2 compatible

# !tf_upgrade_v2 --intree gdrive/My\ Drive/tensorflow-wavenet/ --outtree gdrive/My\ Drive/tensorflow-wavenet/new
# Out:
# INFO line 128:16: Added keywords to args of function 'tf.cond'
# INFO line 128:24: Added keywords to args of function 'tf.size'
# INFO line 129:32: Added keywords to args of function 'tf.size'
# INFO line 142:11: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 158:14: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 166:17: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 170:38: Renamed 'tf.global_variables' to 'tf.compat.v1.global_variables'
# INFO line 172:12: Renamed 'tf.train.Saver' to 'tf.compat.v1.train.Saver'
# INFO line 263:13: tf.summary.FileWriter requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 263:13: Renamed 'tf.summary.FileWriter' to 'tf.compat.v1.summary.FileWriter'
# INFO line 264:4: tf.summary.audio requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 264:4: Renamed 'tf.summary.audio' to 'tf.compat.v1.summary.audio'
# INFO line 265:16: tf.summary.merge_all requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 265:16: Renamed 'tf.summary.merge_all' to 'tf.compat.v1.summary.merge_all'
# WARNING line 118:4: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
# INFO line 212:9: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 212:9: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 259:16: Renamed 'tf.trainable_variables' to 'tf.compat.v1.trainable_variables'
# INFO line 263:13: tf.summary.FileWriter requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 263:13: Renamed 'tf.summary.FileWriter' to 'tf.compat.v1.summary.FileWriter'
# INFO line 264:21: Renamed 'tf.get_default_graph' to 'tf.compat.v1.get_default_graph'
# INFO line 265:19: Renamed 'tf.RunMetadata' to 'tf.compat.v1.RunMetadata'
# INFO line 266:16: tf.summary.merge_all requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 266:16: Renamed 'tf.summary.merge_all' to 'tf.compat.v1.summary.merge_all'
# INFO line 269:11: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 269:29: Renamed 'tf.ConfigProto' to 'tf.compat.v1.ConfigProto'
# INFO line 270:11: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 274:12: Renamed 'tf.train.Saver' to 'tf.compat.v1.train.Saver'
# INFO line 274:36: Renamed 'tf.trainable_variables' to 'tf.compat.v1.trainable_variables'
# INFO line 289:14: Renamed 'tf.train.start_queue_runners' to 'tf.compat.v1.train.start_queue_runners'
# INFO line 300:30: Renamed 'tf.RunOptions' to 'tf.compat.v1.RunOptions'
# INFO line 301:32: Renamed 'tf.RunOptions' to 'tf.compat.v1.RunOptions'
# INFO line 22:19: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 28:21: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 37:19: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 43:21: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 51:19: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 57:21: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 96:26: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 97:21: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 196:16: Renamed 'tf.train.Saver' to 'tf.compat.v1.train.Saver'
# INFO line 196:40: Renamed 'tf.trainable_variables' to 'tf.compat.v1.trainable_variables'
# WARNING line 197:8: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
# INFO line 231:28: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 232:25: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 239:20: Renamed 'tf.trainable_variables' to 'tf.compat.v1.trainable_variables'
# INFO line 241:15: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 7:11: Renamed 'tf.train.AdamOptimizer' to 'tf.compat.v1.train.AdamOptimizer'
# INFO line 12:11: Renamed 'tf.train.MomentumOptimizer' to 'tf.compat.v1.train.MomentumOptimizer'
# INFO line 17:11: Renamed 'tf.train.RMSPropOptimizer' to 'tf.compat.v1.train.RMSPropOptimizer'
# INFO line 28:9: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 28:9: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 29:16: Added keywords to args of function 'tf.shape'
# INFO line 31:17: Added keywords to args of function 'tf.pad'
# INFO line 33:21: Added keywords to args of function 'tf.transpose'
# INFO line 38:9: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 38:9: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 39:16: Added keywords to args of function 'tf.shape'
# INFO line 41:21: Added keywords to args of function 'tf.transpose'
# INFO line 43:27: Renamed 'tf.div' to 'tf.compat.v1.div'
# INFO line 47:9: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 47:9: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 48:23: Added keywords to args of function 'tf.shape'
# INFO line 51:19: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 51:19: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 55:23: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 55:23: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 57:20: Added keywords to args of function 'tf.shape'
# INFO line 66:9: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 66:9: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 67:13: Changed tf.to_float call to tf.cast(..., dtype=tf.float32).
# INFO line 72:20: Renamed 'tf.log1p' to 'tf.math.log1p'
# INFO line 72:52: Renamed 'tf.log1p' to 'tf.math.log1p'
# INFO line 75:15: Changed tf.to_int32 call to tf.cast(..., dtype=tf.int32).
# INFO line 80:9: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 80:9: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 83:22: Changed tf.to_float call to tf.cast(..., dtype=tf.float32).
# INFO line 9:0: Not upgrading symbols because `tensorflow.compat.v1` was directly imported as `tf`.
# INFO line 10:18: Changing tf.contrib.layers xavier initializer to a tf.compat.v1.keras.initializers.VarianceScaling and converting arguments.
#
# INFO line 27:18: tf.constant_initializer requires manual check. Initializers no longer have the dtype argument in the constructor or partition_info argument in the __call__ method.
# The calls have been converted to compat.v1 for safety (even though they may already have been correct).
# INFO line 27:18: Renamed 'tf.constant_initializer' to 'tf.compat.v1.constant_initializer'
# INFO line 134:13: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 142:21: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 150:17: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 166:17: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 168:25: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 217:17: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 241:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 241:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 283:40: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 283:40: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 289:36: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 289:36: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 305:22: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 305:22: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 309:19: Added keywords to args of function 'tf.shape'
# INFO line 312:28: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 312:28: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 333:20: Added keywords to args of function 'tf.shape'
# INFO line 333:47: Added keywords to args of function 'tf.shape'
# INFO line 348:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 348:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 403:23: Added keywords to args of function 'tf.shape'
# INFO line 406:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 406:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 408:21: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 408:21: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 414:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 414:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 434:20: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 434:20: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 438:20: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 438:20: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 451:12: Renamed 'tf.FIFOQueue' to 'tf.queue.FIFOQueue'
# INFO line 467:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 467:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 469:21: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 469:21: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 471:24: Renamed 'tf.FIFOQueue' to 'tf.queue.FIFOQueue'
# INFO line 491:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 491:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 522:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 522:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 543:24: Added keywords to args of function 'tf.nn.embedding_lookup'
# WARNING line 543:24: tf.nn.embedding_lookup requires manual check. `partition_strategy` has been removed from tf.nn.embedding_lookup.  The 'div' strategy will be used by default.
# INFO line 573:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 573:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 588:17: Added keywords to args of function 'tf.shape'
# INFO line 603:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 603:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 613:17: Added keywords to args of function 'tf.shape'
# INFO line 626:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 626:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 641:34: Added keywords to args of function 'tf.shape'
# INFO line 647:17: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 647:17: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 660:23: Changing labels arg of tf.nn.softmax_cross_entropy_with_logits to tf.stop_gradient(labels). Please check this transformation.
#
# INFO line 663:31: Added keywords to args of function 'tf.reduce_mean'
# INFO line 665:16: tf.summary.scalar requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 665:16: Renamed 'tf.summary.scalar' to 'tf.compat.v1.summary.scalar'
# INFO line 672:49: Renamed 'tf.trainable_variables' to 'tf.compat.v1.trainable_variables'
# INFO line 679:20: tf.summary.scalar requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 679:20: Renamed 'tf.summary.scalar' to 'tf.compat.v1.summary.scalar'
# INFO line 680:20: tf.summary.scalar requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 680:20: Renamed 'tf.summary.scalar' to 'tf.compat.v1.summary.scalar'
# TensorFlow 2.0 Upgrade Script
# -----------------------------
# Converted 10 files
# Detected 3 issues that require attention
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# File: gdrive/My Drive/tensorflow-wavenet/train.py
# --------------------------------------------------------------------------------
# gdrive/My Drive/tensorflow-wavenet/train.py:118:4: WARNING: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
# --------------------------------------------------------------------------------
# File: gdrive/My Drive/tensorflow-wavenet/wavenet/model.py
# --------------------------------------------------------------------------------
# gdrive/My Drive/tensorflow-wavenet/wavenet/model.py:543:24: WARNING: tf.nn.embedding_lookup requires manual check. `partition_strategy` has been removed from tf.nn.embedding_lookup.  The 'div' strategy will be used by default.
# --------------------------------------------------------------------------------
# File: gdrive/My Drive/tensorflow-wavenet/test/test_model.py
# --------------------------------------------------------------------------------
# gdrive/My Drive/tensorflow-wavenet/test/test_model.py:197:8: WARNING: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
#
#
# Make sure to read the detailed log 'report.txt'
