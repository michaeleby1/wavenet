# %% [markdown]
# <a href="https://colab.research.google.com/github/michaeleby1/wavenet/blob/master/wavenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !cd gdrive/My\ Drive/ && git clone https://github.com/michaeleby1/tensorflow-wavenet
# Out:
# Cloning into 'tensorflow-wavenet'...
# remote: Enumerating objects: 918, done.
# remote: Total 918 (delta 0), reused 0 (delta 0), pack-reused 918
# Receiving objects: 100% (918/918), 344.09 KiB | 472.00 KiB/s, done.
# Resolving deltas: 100% (525/525), done.

# %%
# !pip install librosa

# %%
##make sure tensorflow sees gpu
import tensorflow as tf

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
##downsample audio to 8k hz
import librosa   

y, s = librosa.load('gdrive/My Drive/guitar/jimmypageguitar.wav', sr=8000)
librosa.output.write_wav('gdrive/My Drive/guitar/jimmypageguitar2.wav', y, s)

# %%
# !cd gdrive/My\ Drive/tensorflow-wavenet-new && python train.py --data_dir=/content/gdrive/My\ Drive\/guitar/ --silence_threshold=0.01 --sample_size=16000 --num_steps=9250
# Out:
# Streaming output truncated to the last 5000 lines.
# step 4938 - loss = 2.581, (0.467 sec/step)
# step 4939 - loss = 2.590, (0.468 sec/step)
# step 4940 - loss = 2.651, (0.469 sec/step)
# step 4941 - loss = 2.650, (0.466 sec/step)
# step 4942 - loss = 2.657, (0.466 sec/step)
# step 4943 - loss = 2.580, (0.469 sec/step)
# step 4944 - loss = 2.583, (0.470 sec/step)
# step 4945 - loss = 2.288, (0.470 sec/step)
# step 4946 - loss = 2.230, (0.469 sec/step)
# step 4947 - loss = 2.417, (0.468 sec/step)
# step 4948 - loss = 2.395, (0.467 sec/step)
# step 4949 - loss = 2.499, (0.117 sec/step)
# step 4950 - loss = 2.695, (0.463 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-18T20-50-47 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# ...

# %%
# !cd gdrive/My\ Drive/tensorflow-wavenet-new && python generate.py --wav_out_path=generated_short.wav --save_every 4000 --samples=8000 logdir/train/2020-06-18T20-50-47/model.ckpt-9249
# Out:
# 2020-06-18 22:10:36.651958: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2020-06-18 22:10:38.388341: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-06-18 22:10:38.391540: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-18 22:10:38.392290: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# ...

# %%
##makes code tf2 compatible

# !tf_upgrade_v2 --intree gdrive/My\ Drive/tensorflow-wavenet/ --outtree gdrive/My\ Drive/tensorflow-wavenet/new
# Out:
# INFO line 128:16: Added keywords to args of function 'tf.cond'
# INFO line 128:24: Added keywords to args of function 'tf.size'
# INFO line 129:32: Added keywords to args of function 'tf.size'
# INFO line 142:11: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 158:14: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 166:17: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 170:38: Renamed 'tf.global_variables' to 'tf.compat.v1.global_variables'
# INFO line 172:12: Renamed 'tf.train.Saver' to 'tf.compat.v1.train.Saver'
# ...
