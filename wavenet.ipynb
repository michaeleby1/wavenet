# %% [markdown]
# <a href="https://colab.research.google.com/github/michaeleby1/wavenet/blob/master/wavenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !cd gdrive/My\ Drive/ && git clone https://github.com/michaeleby1/tensorflow-wavenet
# Out:
# Cloning into 'tensorflow-wavenet'...
# remote: Enumerating objects: 918, done.
# remote: Total 918 (delta 0), reused 0 (delta 0), pack-reused 918
# Receiving objects: 100% (918/918), 344.09 KiB | 472.00 KiB/s, done.
# Resolving deltas: 100% (525/525), done.

# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.6/dist-packages (0.6.3)
# Requirement already satisfied: joblib>=0.12 in /usr/local/lib/python3.6/dist-packages (from librosa) (0.15.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (0.22.2.post1)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.38.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (0.48.0)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (1.18.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (1.4.1)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.6/dist-packages (from librosa) (1.12.0)
# Requirement already satisfied: resampy>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (0.2.2)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (2.1.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba>=0.38.0->librosa) (47.3.1)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba>=0.38.0->librosa) (0.31.0)

# %%
##make sure tensorflow sees gpu
import tensorflow as tf

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
##downsample audio to 8k hz
import librosa   

y, s = librosa.load('gdrive/My Drive/guitar/chopin.mp3', sr=8000)
librosa.output.write_wav('gdrive/My Drive/guitar/chopin.wav', y, s)

# %%
# !cd gdrive/My\ Drive/tensorflow-wavenet-new && python train.py --data_dir=/content/gdrive/My\ Drive\/guitar/ --silence_threshold=0.3 --sample_size=16000 --num_steps=9250
# Out:
# Streaming output truncated to the last 5000 lines.
# step 5858 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 5859 - loss = 0.000, (3.405 sec/step)
# step 5860 - loss = 0.000, (0.473 sec/step)
# step 5861 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 5862 - loss = 0.000, (3.425 sec/step)
# step 5863 - loss = 0.000, (0.469 sec/step)
# step 5864 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 5865 - loss = 0.000, (3.486 sec/step)
# step 5866 - loss = 0.000, (0.481 sec/step)
# step 5867 - loss = 0.000, (0.345 sec/step)
# files length: 1
# step 5868 - loss = 0.000, (3.573 sec/step)
# step 5869 - loss = 0.000, (0.474 sec/step)
# step 5870 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 5871 - loss = 0.000, (3.505 sec/step)
# step 5872 - loss = 0.000, (0.475 sec/step)
# step 5873 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 5874 - loss = 0.000, (3.478 sec/step)
# step 5875 - loss = 0.000, (0.472 sec/step)
# step 5876 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 5877 - loss = 0.000, (3.535 sec/step)
# step 5878 - loss = 0.000, (0.468 sec/step)
# step 5879 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 5880 - loss = 0.000, (3.455 sec/step)
# step 5881 - loss = 0.000, (0.480 sec/step)
# step 5882 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 5883 - loss = 0.000, (3.559 sec/step)
# step 5884 - loss = 0.000, (0.476 sec/step)
# step 5885 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 5886 - loss = 0.000, (3.592 sec/step)
# step 5887 - loss = 0.000, (0.471 sec/step)
# step 5888 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 5889 - loss = 0.000, (3.487 sec/step)
# step 5890 - loss = 0.000, (0.474 sec/step)
# step 5891 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 5892 - loss = 0.000, (3.447 sec/step)
# step 5893 - loss = 0.000, (0.473 sec/step)
# step 5894 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 5895 - loss = 0.000, (3.477 sec/step)
# step 5896 - loss = 0.000, (0.480 sec/step)
# step 5897 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 5898 - loss = 0.000, (3.537 sec/step)
# step 5899 - loss = 0.000, (0.475 sec/step)
# step 5900 - loss = 0.000, (0.336 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# files length: 1
# step 5901 - loss = 0.000, (1.967 sec/step)
# step 5902 - loss = 0.000, (0.472 sec/step)
# step 5903 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 5904 - loss = 0.000, (3.409 sec/step)
# step 5905 - loss = 0.000, (0.473 sec/step)
# step 5906 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 5907 - loss = 0.000, (3.558 sec/step)
# step 5908 - loss = 0.000, (0.474 sec/step)
# step 5909 - loss = 0.000, (0.335 sec/step)
# files length: 1
# step 5910 - loss = 0.000, (3.639 sec/step)
# step 5911 - loss = 0.000, (0.473 sec/step)
# step 5912 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 5913 - loss = 0.000, (3.422 sec/step)
# step 5914 - loss = 0.000, (0.471 sec/step)
# step 5915 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 5916 - loss = 0.000, (3.408 sec/step)
# step 5917 - loss = 0.000, (0.488 sec/step)
# step 5918 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 5919 - loss = 0.000, (3.454 sec/step)
# step 5920 - loss = 0.000, (0.475 sec/step)
# step 5921 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 5922 - loss = 0.000, (3.529 sec/step)
# step 5923 - loss = 0.000, (0.471 sec/step)
# step 5924 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 5925 - loss = 0.000, (3.425 sec/step)
# step 5926 - loss = 0.000, (0.471 sec/step)
# step 5927 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 5928 - loss = 0.000, (3.408 sec/step)
# step 5929 - loss = 0.000, (0.472 sec/step)
# step 5930 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 5931 - loss = 0.000, (3.497 sec/step)
# step 5932 - loss = 0.000, (0.475 sec/step)
# step 5933 - loss = 0.000, (0.334 sec/step)
# files length: 1
# step 5934 - loss = 0.000, (3.441 sec/step)
# step 5935 - loss = 0.000, (0.471 sec/step)
# step 5936 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 5937 - loss = 0.000, (3.418 sec/step)
# step 5938 - loss = 0.000, (0.476 sec/step)
# step 5939 - loss = 0.000, (0.344 sec/step)
# files length: 1
# step 5940 - loss = 0.000, (3.441 sec/step)
# step 5941 - loss = 0.000, (0.469 sec/step)
# step 5942 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 5943 - loss = 0.000, (3.478 sec/step)
# step 5944 - loss = 0.000, (0.464 sec/step)
# step 5945 - loss = 0.000, (0.343 sec/step)
# files length: 1
# step 5946 - loss = 0.000, (3.336 sec/step)
# step 5947 - loss = 0.000, (0.474 sec/step)
# step 5948 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 5949 - loss = 0.000, (3.543 sec/step)
# step 5950 - loss = 0.000, (0.471 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 5951 - loss = 0.000, (0.333 sec/step)
# files length: 1
# step 5952 - loss = 0.000, (1.972 sec/step)
# step 5953 - loss = 0.000, (0.472 sec/step)
# step 5954 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 5955 - loss = 0.000, (3.497 sec/step)
# step 5956 - loss = 0.000, (0.472 sec/step)
# step 5957 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 5958 - loss = 0.000, (3.598 sec/step)
# step 5959 - loss = 0.000, (0.473 sec/step)
# step 5960 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 5961 - loss = 0.000, (3.435 sec/step)
# step 5962 - loss = 0.000, (0.472 sec/step)
# step 5963 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 5964 - loss = 0.000, (3.349 sec/step)
# step 5965 - loss = 0.000, (0.467 sec/step)
# step 5966 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 5967 - loss = 0.000, (3.534 sec/step)
# step 5968 - loss = 0.000, (0.479 sec/step)
# step 5969 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 5970 - loss = 0.000, (3.413 sec/step)
# step 5971 - loss = 0.000, (0.470 sec/step)
# step 5972 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 5973 - loss = 0.000, (3.457 sec/step)
# step 5974 - loss = 0.000, (0.472 sec/step)
# step 5975 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 5976 - loss = 0.000, (3.528 sec/step)
# step 5977 - loss = 0.000, (0.475 sec/step)
# step 5978 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 5979 - loss = 0.000, (3.473 sec/step)
# step 5980 - loss = 0.000, (0.475 sec/step)
# step 5981 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 5982 - loss = 0.000, (3.458 sec/step)
# step 5983 - loss = 0.000, (0.468 sec/step)
# step 5984 - loss = 0.000, (0.334 sec/step)
# files length: 1
# step 5985 - loss = 0.000, (3.467 sec/step)
# step 5986 - loss = 0.000, (0.472 sec/step)
# step 5987 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 5988 - loss = 0.000, (3.376 sec/step)
# step 5989 - loss = 0.000, (0.470 sec/step)
# step 5990 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 5991 - loss = 0.000, (3.474 sec/step)
# step 5992 - loss = 0.000, (0.476 sec/step)
# step 5993 - loss = 0.000, (0.334 sec/step)
# files length: 1
# step 5994 - loss = 0.000, (3.435 sec/step)
# step 5995 - loss = 0.000, (0.469 sec/step)
# step 5996 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 5997 - loss = 0.000, (3.380 sec/step)
# step 5998 - loss = 0.000, (0.476 sec/step)
# step 5999 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6000 - loss = 0.000, (3.517 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 6001 - loss = 0.000, (0.465 sec/step)
# step 6002 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6003 - loss = 0.000, (1.907 sec/step)
# step 6004 - loss = 0.000, (0.471 sec/step)
# step 6005 - loss = 0.000, (0.335 sec/step)
# files length: 1
# step 6006 - loss = 0.000, (3.520 sec/step)
# step 6007 - loss = 0.000, (0.475 sec/step)
# step 6008 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 6009 - loss = 0.000, (3.515 sec/step)
# step 6010 - loss = 0.000, (0.470 sec/step)
# step 6011 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6012 - loss = 0.000, (3.545 sec/step)
# step 6013 - loss = 0.000, (0.474 sec/step)
# step 6014 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6015 - loss = 0.000, (3.499 sec/step)
# step 6016 - loss = 0.000, (0.478 sec/step)
# step 6017 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6018 - loss = 0.000, (3.472 sec/step)
# step 6019 - loss = 0.000, (0.468 sec/step)
# step 6020 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6021 - loss = 0.000, (3.518 sec/step)
# step 6022 - loss = 0.000, (0.477 sec/step)
# step 6023 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 6024 - loss = 0.000, (3.492 sec/step)
# step 6025 - loss = 0.000, (0.469 sec/step)
# step 6026 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6027 - loss = 0.000, (3.437 sec/step)
# step 6028 - loss = 0.000, (0.476 sec/step)
# step 6029 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6030 - loss = 0.000, (3.411 sec/step)
# step 6031 - loss = 0.000, (0.475 sec/step)
# step 6032 - loss = 0.000, (0.335 sec/step)
# files length: 1
# step 6033 - loss = 0.000, (3.540 sec/step)
# step 6034 - loss = 0.000, (0.470 sec/step)
# step 6035 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 6036 - loss = 0.000, (3.405 sec/step)
# step 6037 - loss = 0.000, (0.468 sec/step)
# step 6038 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6039 - loss = 0.000, (3.471 sec/step)
# step 6040 - loss = 0.000, (0.470 sec/step)
# step 6041 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6042 - loss = 0.000, (3.636 sec/step)
# step 6043 - loss = 0.000, (0.471 sec/step)
# step 6044 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6045 - loss = 0.000, (3.438 sec/step)
# step 6046 - loss = 0.000, (0.477 sec/step)
# step 6047 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 6048 - loss = 0.000, (3.558 sec/step)
# step 6049 - loss = 0.000, (0.471 sec/step)
# step 6050 - loss = 0.000, (0.339 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# files length: 1
# step 6051 - loss = 0.000, (1.966 sec/step)
# step 6052 - loss = 0.000, (0.472 sec/step)
# step 6053 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6054 - loss = 0.000, (3.541 sec/step)
# step 6055 - loss = 0.000, (0.484 sec/step)
# step 6056 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6057 - loss = 0.000, (3.473 sec/step)
# step 6058 - loss = 0.000, (0.472 sec/step)
# step 6059 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6060 - loss = 0.000, (3.510 sec/step)
# step 6061 - loss = 0.000, (0.474 sec/step)
# step 6062 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6063 - loss = 0.000, (3.453 sec/step)
# step 6064 - loss = 0.000, (0.472 sec/step)
# step 6065 - loss = 0.000, (0.334 sec/step)
# files length: 1
# step 6066 - loss = 0.000, (3.458 sec/step)
# step 6067 - loss = 0.000, (0.474 sec/step)
# step 6068 - loss = 0.000, (0.335 sec/step)
# files length: 1
# step 6069 - loss = 0.000, (3.496 sec/step)
# step 6070 - loss = 0.000, (0.475 sec/step)
# step 6071 - loss = 0.000, (0.344 sec/step)
# files length: 1
# step 6072 - loss = 0.000, (3.621 sec/step)
# step 6073 - loss = 0.000, (0.478 sec/step)
# step 6074 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6075 - loss = 0.000, (3.401 sec/step)
# step 6076 - loss = 0.000, (0.474 sec/step)
# step 6077 - loss = 0.000, (0.334 sec/step)
# files length: 1
# step 6078 - loss = 0.000, (3.421 sec/step)
# step 6079 - loss = 0.000, (0.471 sec/step)
# step 6080 - loss = 0.000, (0.344 sec/step)
# files length: 1
# step 6081 - loss = 0.000, (3.390 sec/step)
# step 6082 - loss = 0.000, (0.472 sec/step)
# step 6083 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6084 - loss = 0.000, (3.454 sec/step)
# step 6085 - loss = 0.000, (0.474 sec/step)
# step 6086 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6087 - loss = 0.000, (3.451 sec/step)
# step 6088 - loss = 0.000, (0.472 sec/step)
# step 6089 - loss = 0.000, (0.343 sec/step)
# files length: 1
# step 6090 - loss = 0.000, (3.409 sec/step)
# step 6091 - loss = 0.000, (0.472 sec/step)
# step 6092 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6093 - loss = 0.000, (3.536 sec/step)
# step 6094 - loss = 0.000, (0.469 sec/step)
# step 6095 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6096 - loss = 0.000, (3.503 sec/step)
# step 6097 - loss = 0.000, (0.477 sec/step)
# step 6098 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6099 - loss = 0.000, (3.537 sec/step)
# step 6100 - loss = 0.000, (0.473 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 6101 - loss = 0.000, (0.344 sec/step)
# files length: 1
# step 6102 - loss = 0.000, (1.947 sec/step)
# step 6103 - loss = 0.000, (0.474 sec/step)
# step 6104 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6105 - loss = 0.000, (3.673 sec/step)
# step 6106 - loss = 0.000, (0.473 sec/step)
# step 6107 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6108 - loss = 0.000, (3.453 sec/step)
# step 6109 - loss = 0.000, (0.476 sec/step)
# step 6110 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6111 - loss = 0.000, (3.597 sec/step)
# step 6112 - loss = 0.000, (0.473 sec/step)
# step 6113 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6114 - loss = 0.000, (3.448 sec/step)
# step 6115 - loss = 0.000, (0.481 sec/step)
# step 6116 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6117 - loss = 0.000, (3.444 sec/step)
# step 6118 - loss = 0.000, (0.476 sec/step)
# step 6119 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6120 - loss = 0.000, (3.569 sec/step)
# step 6121 - loss = 0.000, (0.472 sec/step)
# step 6122 - loss = 0.000, (0.343 sec/step)
# files length: 1
# step 6123 - loss = 0.000, (3.480 sec/step)
# step 6124 - loss = 0.000, (0.471 sec/step)
# step 6125 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6126 - loss = 0.000, (3.513 sec/step)
# step 6127 - loss = 0.000, (0.476 sec/step)
# step 6128 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6129 - loss = 0.000, (3.518 sec/step)
# step 6130 - loss = 0.000, (0.471 sec/step)
# step 6131 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6132 - loss = 0.000, (3.442 sec/step)
# step 6133 - loss = 0.000, (0.472 sec/step)
# step 6134 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6135 - loss = 0.000, (3.468 sec/step)
# step 6136 - loss = 0.000, (0.471 sec/step)
# step 6137 - loss = 0.000, (0.345 sec/step)
# files length: 1
# step 6138 - loss = 0.000, (3.475 sec/step)
# step 6139 - loss = 0.000, (0.468 sec/step)
# step 6140 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6141 - loss = 0.000, (3.531 sec/step)
# step 6142 - loss = 0.000, (0.478 sec/step)
# step 6143 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6144 - loss = 0.000, (3.609 sec/step)
# step 6145 - loss = 0.000, (0.472 sec/step)
# step 6146 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6147 - loss = 0.000, (3.410 sec/step)
# step 6148 - loss = 0.000, (0.473 sec/step)
# step 6149 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 6150 - loss = 0.000, (3.555 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 6151 - loss = 0.000, (0.465 sec/step)
# step 6152 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6153 - loss = 0.000, (1.985 sec/step)
# step 6154 - loss = 0.000, (0.472 sec/step)
# step 6155 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6156 - loss = 0.000, (3.491 sec/step)
# step 6157 - loss = 0.000, (0.472 sec/step)
# step 6158 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 6159 - loss = 0.000, (3.676 sec/step)
# step 6160 - loss = 0.000, (0.472 sec/step)
# step 6161 - loss = 0.000, (0.347 sec/step)
# files length: 1
# step 6162 - loss = 0.000, (3.577 sec/step)
# step 6163 - loss = 0.000, (0.474 sec/step)
# step 6164 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6165 - loss = 0.000, (3.525 sec/step)
# step 6166 - loss = 0.000, (0.479 sec/step)
# step 6167 - loss = 0.000, (0.344 sec/step)
# files length: 1
# step 6168 - loss = 0.000, (3.623 sec/step)
# step 6169 - loss = 0.000, (0.476 sec/step)
# step 6170 - loss = 0.000, (0.346 sec/step)
# files length: 1
# step 6171 - loss = 0.000, (3.544 sec/step)
# step 6172 - loss = 0.000, (0.475 sec/step)
# step 6173 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6174 - loss = 0.000, (3.552 sec/step)
# step 6175 - loss = 0.000, (0.473 sec/step)
# step 6176 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6177 - loss = 0.000, (3.503 sec/step)
# step 6178 - loss = 0.000, (0.472 sec/step)
# step 6179 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6180 - loss = 0.000, (3.528 sec/step)
# step 6181 - loss = 0.000, (0.469 sec/step)
# step 6182 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6183 - loss = 0.000, (3.522 sec/step)
# step 6184 - loss = 0.000, (0.474 sec/step)
# step 6185 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6186 - loss = 0.000, (3.478 sec/step)
# step 6187 - loss = 0.000, (0.472 sec/step)
# step 6188 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6189 - loss = 0.000, (3.436 sec/step)
# step 6190 - loss = 0.000, (0.477 sec/step)
# step 6191 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6192 - loss = 0.000, (3.426 sec/step)
# step 6193 - loss = 0.000, (0.481 sec/step)
# step 6194 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6195 - loss = 0.000, (3.493 sec/step)
# step 6196 - loss = 0.000, (0.477 sec/step)
# step 6197 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6198 - loss = 0.000, (3.441 sec/step)
# step 6199 - loss = 0.000, (0.479 sec/step)
# step 6200 - loss = 0.000, (0.339 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# files length: 1
# step 6201 - loss = 0.000, (1.891 sec/step)
# step 6202 - loss = 0.000, (0.471 sec/step)
# step 6203 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6204 - loss = 0.000, (3.486 sec/step)
# step 6205 - loss = 0.000, (0.472 sec/step)
# step 6206 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6207 - loss = 0.000, (3.588 sec/step)
# step 6208 - loss = 0.000, (0.474 sec/step)
# step 6209 - loss = 0.000, (0.334 sec/step)
# files length: 1
# step 6210 - loss = 0.000, (3.429 sec/step)
# step 6211 - loss = 0.000, (0.470 sec/step)
# step 6212 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6213 - loss = 0.000, (3.462 sec/step)
# step 6214 - loss = 0.000, (0.472 sec/step)
# step 6215 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6216 - loss = 0.000, (3.583 sec/step)
# step 6217 - loss = 0.000, (0.477 sec/step)
# step 6218 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6219 - loss = 0.000, (3.394 sec/step)
# step 6220 - loss = 0.000, (0.480 sec/step)
# step 6221 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6222 - loss = 0.000, (3.516 sec/step)
# step 6223 - loss = 0.000, (0.477 sec/step)
# step 6224 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6225 - loss = 0.000, (3.500 sec/step)
# step 6226 - loss = 0.000, (0.473 sec/step)
# step 6227 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6228 - loss = 0.000, (3.379 sec/step)
# step 6229 - loss = 0.000, (0.475 sec/step)
# step 6230 - loss = 0.000, (0.344 sec/step)
# files length: 1
# step 6231 - loss = 0.000, (3.365 sec/step)
# step 6232 - loss = 0.000, (0.479 sec/step)
# step 6233 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6234 - loss = 0.000, (3.347 sec/step)
# step 6235 - loss = 0.000, (0.474 sec/step)
# step 6236 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6237 - loss = 0.000, (3.387 sec/step)
# step 6238 - loss = 0.000, (0.476 sec/step)
# step 6239 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 6240 - loss = 0.000, (3.492 sec/step)
# step 6241 - loss = 0.000, (0.475 sec/step)
# step 6242 - loss = 0.000, (0.335 sec/step)
# files length: 1
# step 6243 - loss = 0.000, (3.514 sec/step)
# step 6244 - loss = 0.000, (0.476 sec/step)
# step 6245 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6246 - loss = 0.000, (3.551 sec/step)
# step 6247 - loss = 0.000, (0.473 sec/step)
# step 6248 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6249 - loss = 0.000, (3.443 sec/step)
# step 6250 - loss = 0.000, (0.475 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 6251 - loss = 0.000, (0.345 sec/step)
# files length: 1
# step 6252 - loss = 0.000, (1.960 sec/step)
# step 6253 - loss = 0.000, (0.478 sec/step)
# step 6254 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6255 - loss = 0.000, (3.497 sec/step)
# step 6256 - loss = 0.000, (0.473 sec/step)
# step 6257 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6258 - loss = 0.000, (3.531 sec/step)
# step 6259 - loss = 0.000, (0.483 sec/step)
# step 6260 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6261 - loss = 0.000, (3.492 sec/step)
# step 6262 - loss = 0.000, (0.473 sec/step)
# step 6263 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6264 - loss = 0.000, (3.455 sec/step)
# step 6265 - loss = 0.000, (0.472 sec/step)
# step 6266 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6267 - loss = 0.000, (3.420 sec/step)
# step 6268 - loss = 0.000, (0.474 sec/step)
# step 6269 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6270 - loss = 0.000, (3.333 sec/step)
# step 6271 - loss = 0.000, (0.475 sec/step)
# step 6272 - loss = 0.000, (0.335 sec/step)
# files length: 1
# step 6273 - loss = 0.000, (3.412 sec/step)
# step 6274 - loss = 0.000, (0.473 sec/step)
# step 6275 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6276 - loss = 0.000, (3.386 sec/step)
# step 6277 - loss = 0.000, (0.472 sec/step)
# step 6278 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6279 - loss = 0.000, (3.383 sec/step)
# step 6280 - loss = 0.000, (0.470 sec/step)
# step 6281 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6282 - loss = 0.000, (3.547 sec/step)
# step 6283 - loss = 0.000, (0.479 sec/step)
# step 6284 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6285 - loss = 0.000, (3.390 sec/step)
# step 6286 - loss = 0.000, (0.471 sec/step)
# step 6287 - loss = 0.000, (0.344 sec/step)
# files length: 1
# step 6288 - loss = 0.000, (3.435 sec/step)
# step 6289 - loss = 0.000, (0.472 sec/step)
# step 6290 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 6291 - loss = 0.000, (3.390 sec/step)
# step 6292 - loss = 0.000, (0.476 sec/step)
# step 6293 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6294 - loss = 0.000, (3.319 sec/step)
# step 6295 - loss = 0.000, (0.472 sec/step)
# step 6296 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6297 - loss = 0.000, (3.514 sec/step)
# step 6298 - loss = 0.000, (0.473 sec/step)
# step 6299 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6300 - loss = 0.000, (3.439 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 6301 - loss = 0.000, (0.463 sec/step)
# step 6302 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6303 - loss = 0.000, (1.876 sec/step)
# step 6304 - loss = 0.000, (0.479 sec/step)
# step 6305 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6306 - loss = 0.000, (3.431 sec/step)
# step 6307 - loss = 0.000, (0.468 sec/step)
# step 6308 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6309 - loss = 0.000, (3.426 sec/step)
# step 6310 - loss = 0.000, (0.469 sec/step)
# step 6311 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6312 - loss = 0.000, (3.433 sec/step)
# step 6313 - loss = 0.000, (0.472 sec/step)
# step 6314 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6315 - loss = 0.000, (3.427 sec/step)
# step 6316 - loss = 0.000, (0.472 sec/step)
# step 6317 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6318 - loss = 0.000, (3.378 sec/step)
# step 6319 - loss = 0.000, (0.467 sec/step)
# step 6320 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6321 - loss = 0.000, (3.491 sec/step)
# step 6322 - loss = 0.000, (0.471 sec/step)
# step 6323 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6324 - loss = 0.000, (3.431 sec/step)
# step 6325 - loss = 0.000, (0.481 sec/step)
# step 6326 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6327 - loss = 0.000, (3.402 sec/step)
# step 6328 - loss = 0.000, (0.470 sec/step)
# step 6329 - loss = 0.000, (0.344 sec/step)
# files length: 1
# step 6330 - loss = 0.000, (3.606 sec/step)
# step 6331 - loss = 0.000, (0.472 sec/step)
# step 6332 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6333 - loss = 0.000, (3.464 sec/step)
# step 6334 - loss = 0.000, (0.471 sec/step)
# step 6335 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6336 - loss = 0.000, (3.485 sec/step)
# step 6337 - loss = 0.000, (0.475 sec/step)
# step 6338 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6339 - loss = 0.000, (3.456 sec/step)
# step 6340 - loss = 0.000, (0.471 sec/step)
# step 6341 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6342 - loss = 0.000, (3.403 sec/step)
# step 6343 - loss = 0.000, (0.471 sec/step)
# step 6344 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6345 - loss = 0.000, (3.425 sec/step)
# step 6346 - loss = 0.000, (0.474 sec/step)
# step 6347 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6348 - loss = 0.000, (3.480 sec/step)
# step 6349 - loss = 0.000, (0.471 sec/step)
# step 6350 - loss = 0.000, (0.342 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# files length: 1
# step 6351 - loss = 0.000, (1.908 sec/step)
# step 6352 - loss = 0.000, (0.479 sec/step)
# step 6353 - loss = 0.000, (0.343 sec/step)
# files length: 1
# step 6354 - loss = 0.000, (3.492 sec/step)
# step 6355 - loss = 0.000, (0.473 sec/step)
# step 6356 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6357 - loss = 0.000, (3.434 sec/step)
# step 6358 - loss = 0.000, (0.475 sec/step)
# step 6359 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6360 - loss = 0.000, (3.574 sec/step)
# step 6361 - loss = 0.000, (0.471 sec/step)
# step 6362 - loss = 0.000, (0.335 sec/step)
# files length: 1
# step 6363 - loss = 0.000, (3.400 sec/step)
# step 6364 - loss = 0.000, (0.472 sec/step)
# step 6365 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6366 - loss = 0.000, (3.501 sec/step)
# step 6367 - loss = 0.000, (0.476 sec/step)
# step 6368 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6369 - loss = 0.000, (3.499 sec/step)
# step 6370 - loss = 0.000, (0.473 sec/step)
# step 6371 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6372 - loss = 0.000, (3.474 sec/step)
# step 6373 - loss = 0.000, (0.471 sec/step)
# step 6374 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6375 - loss = 0.000, (3.445 sec/step)
# step 6376 - loss = 0.000, (0.475 sec/step)
# step 6377 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6378 - loss = 0.000, (3.445 sec/step)
# step 6379 - loss = 0.000, (0.472 sec/step)
# step 6380 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6381 - loss = 0.000, (3.474 sec/step)
# step 6382 - loss = 0.000, (0.471 sec/step)
# step 6383 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6384 - loss = 0.000, (3.538 sec/step)
# step 6385 - loss = 0.000, (0.469 sec/step)
# step 6386 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6387 - loss = 0.000, (3.410 sec/step)
# step 6388 - loss = 0.000, (0.471 sec/step)
# step 6389 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6390 - loss = 0.000, (3.404 sec/step)
# step 6391 - loss = 0.000, (0.473 sec/step)
# step 6392 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6393 - loss = 0.000, (3.474 sec/step)
# step 6394 - loss = 0.000, (0.472 sec/step)
# step 6395 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6396 - loss = 0.000, (3.392 sec/step)
# step 6397 - loss = 0.000, (0.470 sec/step)
# step 6398 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 6399 - loss = 0.000, (3.433 sec/step)
# step 6400 - loss = 0.000, (0.474 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 6401 - loss = 0.000, (0.335 sec/step)
# files length: 1
# step 6402 - loss = 0.000, (1.886 sec/step)
# step 6403 - loss = 0.000, (0.472 sec/step)
# step 6404 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6405 - loss = 0.000, (3.401 sec/step)
# step 6406 - loss = 0.000, (0.471 sec/step)
# step 6407 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6408 - loss = 0.000, (3.461 sec/step)
# step 6409 - loss = 0.000, (0.473 sec/step)
# step 6410 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6411 - loss = 0.000, (3.438 sec/step)
# step 6412 - loss = 0.000, (0.470 sec/step)
# step 6413 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6414 - loss = 0.000, (3.443 sec/step)
# step 6415 - loss = 0.000, (0.471 sec/step)
# step 6416 - loss = 0.000, (0.334 sec/step)
# files length: 1
# step 6417 - loss = 0.000, (3.393 sec/step)
# step 6418 - loss = 0.000, (0.472 sec/step)
# step 6419 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6420 - loss = 0.000, (3.424 sec/step)
# step 6421 - loss = 0.000, (0.472 sec/step)
# step 6422 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6423 - loss = 0.000, (3.373 sec/step)
# step 6424 - loss = 0.000, (0.471 sec/step)
# step 6425 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6426 - loss = 0.000, (3.556 sec/step)
# step 6427 - loss = 0.000, (0.468 sec/step)
# step 6428 - loss = 0.000, (0.343 sec/step)
# files length: 1
# step 6429 - loss = 0.000, (3.357 sec/step)
# step 6430 - loss = 0.000, (0.468 sec/step)
# step 6431 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6432 - loss = 0.000, (3.601 sec/step)
# step 6433 - loss = 0.000, (0.473 sec/step)
# step 6434 - loss = 0.000, (0.343 sec/step)
# files length: 1
# step 6435 - loss = 0.000, (3.494 sec/step)
# step 6436 - loss = 0.000, (0.474 sec/step)
# step 6437 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6438 - loss = 0.000, (3.480 sec/step)
# step 6439 - loss = 0.000, (0.475 sec/step)
# step 6440 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6441 - loss = 0.000, (3.339 sec/step)
# step 6442 - loss = 0.000, (0.469 sec/step)
# step 6443 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6444 - loss = 0.000, (3.312 sec/step)
# step 6445 - loss = 0.000, (0.468 sec/step)
# step 6446 - loss = 0.000, (0.344 sec/step)
# files length: 1
# step 6447 - loss = 0.000, (3.396 sec/step)
# step 6448 - loss = 0.000, (0.476 sec/step)
# step 6449 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6450 - loss = 0.000, (3.367 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 6451 - loss = 0.000, (0.465 sec/step)
# step 6452 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6453 - loss = 0.000, (2.046 sec/step)
# step 6454 - loss = 0.000, (0.470 sec/step)
# step 6455 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6456 - loss = 0.000, (3.429 sec/step)
# step 6457 - loss = 0.000, (0.471 sec/step)
# step 6458 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6459 - loss = 0.000, (3.596 sec/step)
# step 6460 - loss = 0.000, (0.469 sec/step)
# step 6461 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6462 - loss = 0.000, (3.461 sec/step)
# step 6463 - loss = 0.000, (0.473 sec/step)
# step 6464 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6465 - loss = 0.000, (3.481 sec/step)
# step 6466 - loss = 0.000, (0.471 sec/step)
# step 6467 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6468 - loss = 0.000, (3.466 sec/step)
# step 6469 - loss = 0.000, (0.477 sec/step)
# step 6470 - loss = 0.000, (0.344 sec/step)
# files length: 1
# step 6471 - loss = 0.000, (3.535 sec/step)
# step 6472 - loss = 0.000, (0.472 sec/step)
# step 6473 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6474 - loss = 0.000, (3.531 sec/step)
# step 6475 - loss = 0.000, (0.472 sec/step)
# step 6476 - loss = 0.000, (0.343 sec/step)
# files length: 1
# step 6477 - loss = 0.000, (3.533 sec/step)
# step 6478 - loss = 0.000, (0.472 sec/step)
# step 6479 - loss = 0.000, (0.343 sec/step)
# files length: 1
# step 6480 - loss = 0.000, (3.396 sec/step)
# step 6481 - loss = 0.000, (0.476 sec/step)
# step 6482 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6483 - loss = 0.000, (3.514 sec/step)
# step 6484 - loss = 0.000, (0.476 sec/step)
# step 6485 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6486 - loss = 0.000, (3.474 sec/step)
# step 6487 - loss = 0.000, (0.467 sec/step)
# step 6488 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6489 - loss = 0.000, (3.406 sec/step)
# step 6490 - loss = 0.000, (0.475 sec/step)
# step 6491 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6492 - loss = 0.000, (3.631 sec/step)
# step 6493 - loss = 0.000, (0.476 sec/step)
# step 6494 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6495 - loss = 0.000, (3.474 sec/step)
# step 6496 - loss = 0.000, (0.487 sec/step)
# step 6497 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 6498 - loss = 0.000, (3.424 sec/step)
# step 6499 - loss = 0.000, (0.477 sec/step)
# step 6500 - loss = 0.000, (0.343 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# files length: 1
# step 6501 - loss = 0.000, (1.993 sec/step)
# step 6502 - loss = 0.000, (0.469 sec/step)
# step 6503 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6504 - loss = 0.000, (3.563 sec/step)
# step 6505 - loss = 0.000, (0.472 sec/step)
# step 6506 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6507 - loss = 0.000, (3.484 sec/step)
# step 6508 - loss = 0.000, (0.476 sec/step)
# step 6509 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6510 - loss = 0.000, (3.497 sec/step)
# step 6511 - loss = 0.000, (0.470 sec/step)
# step 6512 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6513 - loss = 0.000, (3.428 sec/step)
# step 6514 - loss = 0.000, (0.474 sec/step)
# step 6515 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6516 - loss = 0.000, (3.432 sec/step)
# step 6517 - loss = 0.000, (0.473 sec/step)
# step 6518 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6519 - loss = 0.000, (3.445 sec/step)
# step 6520 - loss = 0.000, (0.469 sec/step)
# step 6521 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6522 - loss = 0.000, (3.444 sec/step)
# step 6523 - loss = 0.000, (0.471 sec/step)
# step 6524 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6525 - loss = 0.000, (3.575 sec/step)
# step 6526 - loss = 0.000, (0.469 sec/step)
# step 6527 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6528 - loss = 0.000, (3.464 sec/step)
# step 6529 - loss = 0.000, (0.475 sec/step)
# step 6530 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6531 - loss = 0.000, (3.480 sec/step)
# step 6532 - loss = 0.000, (0.470 sec/step)
# step 6533 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6534 - loss = 0.000, (3.477 sec/step)
# step 6535 - loss = 0.000, (0.467 sec/step)
# step 6536 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6537 - loss = 0.000, (3.447 sec/step)
# step 6538 - loss = 0.000, (0.473 sec/step)
# step 6539 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6540 - loss = 0.000, (3.514 sec/step)
# step 6541 - loss = 0.000, (0.475 sec/step)
# step 6542 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6543 - loss = 0.000, (3.465 sec/step)
# step 6544 - loss = 0.000, (0.472 sec/step)
# step 6545 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6546 - loss = 0.000, (3.513 sec/step)
# step 6547 - loss = 0.000, (0.472 sec/step)
# step 6548 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6549 - loss = 0.000, (3.547 sec/step)
# step 6550 - loss = 0.000, (0.472 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 6551 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6552 - loss = 0.000, (1.938 sec/step)
# step 6553 - loss = 0.000, (0.475 sec/step)
# step 6554 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6555 - loss = 0.000, (3.509 sec/step)
# step 6556 - loss = 0.000, (0.465 sec/step)
# step 6557 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6558 - loss = 0.000, (3.429 sec/step)
# step 6559 - loss = 0.000, (0.469 sec/step)
# step 6560 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6561 - loss = 0.000, (3.407 sec/step)
# step 6562 - loss = 0.000, (0.471 sec/step)
# step 6563 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6564 - loss = 0.000, (3.472 sec/step)
# step 6565 - loss = 0.000, (0.476 sec/step)
# step 6566 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6567 - loss = 0.000, (3.432 sec/step)
# step 6568 - loss = 0.000, (0.470 sec/step)
# step 6569 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6570 - loss = 0.000, (3.424 sec/step)
# step 6571 - loss = 0.000, (0.472 sec/step)
# step 6572 - loss = 0.000, (0.335 sec/step)
# files length: 1
# step 6573 - loss = 0.000, (3.535 sec/step)
# step 6574 - loss = 0.000, (0.469 sec/step)
# step 6575 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6576 - loss = 0.000, (3.403 sec/step)
# step 6577 - loss = 0.000, (0.477 sec/step)
# step 6578 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6579 - loss = 0.000, (3.446 sec/step)
# step 6580 - loss = 0.000, (0.477 sec/step)
# step 6581 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6582 - loss = 0.000, (3.486 sec/step)
# step 6583 - loss = 0.000, (0.473 sec/step)
# step 6584 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6585 - loss = 0.000, (3.482 sec/step)
# step 6586 - loss = 0.000, (0.469 sec/step)
# step 6587 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6588 - loss = 0.000, (3.573 sec/step)
# step 6589 - loss = 0.000, (0.471 sec/step)
# step 6590 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6591 - loss = 0.000, (3.502 sec/step)
# step 6592 - loss = 0.000, (0.478 sec/step)
# step 6593 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6594 - loss = 0.000, (3.641 sec/step)
# step 6595 - loss = 0.000, (0.473 sec/step)
# step 6596 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6597 - loss = 0.000, (3.398 sec/step)
# step 6598 - loss = 0.000, (0.468 sec/step)
# step 6599 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6600 - loss = 0.000, (3.511 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 6601 - loss = 0.000, (0.465 sec/step)
# step 6602 - loss = 0.000, (0.343 sec/step)
# files length: 1
# step 6603 - loss = 0.000, (1.868 sec/step)
# step 6604 - loss = 0.000, (0.486 sec/step)
# step 6605 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 6606 - loss = 0.000, (3.536 sec/step)
# step 6607 - loss = 0.000, (0.476 sec/step)
# step 6608 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 6609 - loss = 0.000, (3.480 sec/step)
# step 6610 - loss = 0.000, (0.472 sec/step)
# step 6611 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6612 - loss = 0.000, (3.443 sec/step)
# step 6613 - loss = 0.000, (0.480 sec/step)
# step 6614 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 6615 - loss = 0.000, (3.485 sec/step)
# step 6616 - loss = 0.000, (0.473 sec/step)
# step 6617 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 6618 - loss = 0.000, (3.459 sec/step)
# step 6619 - loss = 0.000, (0.479 sec/step)
# step 6620 - loss = 0.000, (0.334 sec/step)
# files length: 1
# step 6621 - loss = 0.000, (3.548 sec/step)
# step 6622 - loss = 0.000, (0.472 sec/step)
# step 6623 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 6624 - loss = 0.000, (3.450 sec/step)
# step 6625 - loss = 0.000, (0.475 sec/step)
# step 6626 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6627 - loss = 0.000, (3.512 sec/step)
# step 6628 - loss = 0.000, (0.470 sec/step)
# step 6629 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 6630 - loss = 0.000, (3.540 sec/step)
# step 6631 - loss = 0.000, (0.471 sec/step)
# step 6632 - loss = 0.000, (0.345 sec/step)
# files length: 1
# step 6633 - loss = 0.000, (3.458 sec/step)
# step 6634 - loss = 0.000, (0.472 sec/step)
# step 6635 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 6636 - loss = 0.000, (3.550 sec/step)
# step 6637 - loss = 0.000, (0.478 sec/step)
# step 6638 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6639 - loss = 0.000, (3.561 sec/step)
# step 6640 - loss = 0.000, (0.471 sec/step)
# step 6641 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 6642 - loss = 0.000, (3.465 sec/step)
# step 6643 - loss = 0.000, (0.484 sec/step)
# step 6644 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 6645 - loss = 0.000, (3.472 sec/step)
# step 6646 - loss = 0.000, (0.482 sec/step)
# step 6647 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 6648 - loss = 0.000, (3.439 sec/step)
# step 6649 - loss = 0.000, (0.471 sec/step)
# step 6650 - loss = 0.000, (0.339 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# ...
# step 8996 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 8997 - loss = 0.000, (3.637 sec/step)
# step 8998 - loss = 0.000, (0.479 sec/step)
# step 8999 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 9000 - loss = 0.000, (3.629 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 9001 - loss = 0.000, (0.541 sec/step)
# step 9002 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 9003 - loss = 0.000, (1.895 sec/step)
# step 9004 - loss = 0.000, (0.472 sec/step)
# step 9005 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9006 - loss = 0.000, (3.488 sec/step)
# step 9007 - loss = 0.000, (0.475 sec/step)
# step 9008 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 9009 - loss = 0.000, (3.602 sec/step)
# step 9010 - loss = 0.000, (0.478 sec/step)
# step 9011 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9012 - loss = 0.000, (3.570 sec/step)
# step 9013 - loss = 0.000, (0.474 sec/step)
# step 9014 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 9015 - loss = 0.000, (3.488 sec/step)
# step 9016 - loss = 0.000, (0.477 sec/step)
# step 9017 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 9018 - loss = 0.000, (3.548 sec/step)
# step 9019 - loss = 0.000, (0.472 sec/step)
# step 9020 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 9021 - loss = 0.000, (3.538 sec/step)
# step 9022 - loss = 0.000, (0.468 sec/step)
# step 9023 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9024 - loss = 0.000, (3.488 sec/step)
# step 9025 - loss = 0.000, (0.476 sec/step)
# step 9026 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 9027 - loss = 0.000, (3.587 sec/step)
# step 9028 - loss = 0.000, (0.478 sec/step)
# step 9029 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 9030 - loss = 0.000, (3.463 sec/step)
# step 9031 - loss = 0.000, (0.473 sec/step)
# step 9032 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 9033 - loss = 0.000, (3.474 sec/step)
# step 9034 - loss = 0.000, (0.467 sec/step)
# step 9035 - loss = 0.000, (0.343 sec/step)
# files length: 1
# step 9036 - loss = 0.000, (3.485 sec/step)
# step 9037 - loss = 0.000, (0.480 sec/step)
# step 9038 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 9039 - loss = 0.000, (3.411 sec/step)
# step 9040 - loss = 0.000, (0.476 sec/step)
# step 9041 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9042 - loss = 0.000, (3.590 sec/step)
# step 9043 - loss = 0.000, (0.474 sec/step)
# step 9044 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 9045 - loss = 0.000, (3.451 sec/step)
# step 9046 - loss = 0.000, (0.472 sec/step)
# step 9047 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 9048 - loss = 0.000, (3.471 sec/step)
# step 9049 - loss = 0.000, (0.472 sec/step)
# step 9050 - loss = 0.000, (0.341 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# files length: 1
# step 9051 - loss = 0.000, (1.910 sec/step)
# step 9052 - loss = 0.000, (0.474 sec/step)
# step 9053 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 9054 - loss = 0.000, (3.538 sec/step)
# step 9055 - loss = 0.000, (0.482 sec/step)
# step 9056 - loss = 0.000, (0.333 sec/step)
# files length: 1
# step 9057 - loss = 0.000, (3.567 sec/step)
# step 9058 - loss = 0.000, (0.475 sec/step)
# step 9059 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 9060 - loss = 0.000, (3.391 sec/step)
# step 9061 - loss = 0.000, (0.479 sec/step)
# step 9062 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9063 - loss = 0.000, (3.569 sec/step)
# step 9064 - loss = 0.000, (0.472 sec/step)
# step 9065 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 9066 - loss = 0.000, (3.465 sec/step)
# step 9067 - loss = 0.000, (0.468 sec/step)
# step 9068 - loss = 0.000, (0.351 sec/step)
# files length: 1
# step 9069 - loss = 0.000, (3.373 sec/step)
# step 9070 - loss = 0.000, (0.469 sec/step)
# step 9071 - loss = 0.000, (0.335 sec/step)
# files length: 1
# step 9072 - loss = 0.000, (3.428 sec/step)
# step 9073 - loss = 0.000, (0.472 sec/step)
# step 9074 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 9075 - loss = 0.000, (3.385 sec/step)
# step 9076 - loss = 0.000, (0.472 sec/step)
# step 9077 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 9078 - loss = 0.000, (3.471 sec/step)
# step 9079 - loss = 0.000, (0.469 sec/step)
# step 9080 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9081 - loss = 0.000, (3.489 sec/step)
# step 9082 - loss = 0.000, (0.468 sec/step)
# step 9083 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 9084 - loss = 0.000, (3.354 sec/step)
# step 9085 - loss = 0.000, (0.476 sec/step)
# step 9086 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 9087 - loss = 0.000, (3.466 sec/step)
# step 9088 - loss = 0.000, (0.472 sec/step)
# step 9089 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 9090 - loss = 0.000, (3.482 sec/step)
# step 9091 - loss = 0.000, (0.472 sec/step)
# step 9092 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 9093 - loss = 0.000, (3.540 sec/step)
# step 9094 - loss = 0.000, (0.473 sec/step)
# step 9095 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 9096 - loss = 0.000, (3.541 sec/step)
# step 9097 - loss = 0.000, (0.473 sec/step)
# step 9098 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 9099 - loss = 0.000, (3.522 sec/step)
# step 9100 - loss = 0.000, (0.472 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 9101 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9102 - loss = 0.000, (1.839 sec/step)
# step 9103 - loss = 0.000, (0.469 sec/step)
# step 9104 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9105 - loss = 0.000, (3.400 sec/step)
# step 9106 - loss = 0.000, (0.472 sec/step)
# step 9107 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9108 - loss = 0.000, (3.419 sec/step)
# step 9109 - loss = 0.000, (0.470 sec/step)
# step 9110 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 9111 - loss = 0.000, (3.435 sec/step)
# step 9112 - loss = 0.000, (0.475 sec/step)
# step 9113 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9114 - loss = 0.000, (3.557 sec/step)
# step 9115 - loss = 0.000, (0.476 sec/step)
# step 9116 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9117 - loss = 0.000, (3.472 sec/step)
# step 9118 - loss = 0.000, (0.471 sec/step)
# step 9119 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 9120 - loss = 0.000, (3.627 sec/step)
# step 9121 - loss = 0.000, (0.470 sec/step)
# step 9122 - loss = 0.000, (0.343 sec/step)
# files length: 1
# step 9123 - loss = 0.000, (3.394 sec/step)
# step 9124 - loss = 0.000, (0.472 sec/step)
# step 9125 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 9126 - loss = 0.000, (3.444 sec/step)
# step 9127 - loss = 0.000, (0.471 sec/step)
# step 9128 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 9129 - loss = 0.000, (3.538 sec/step)
# step 9130 - loss = 0.000, (0.471 sec/step)
# step 9131 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 9132 - loss = 0.000, (3.441 sec/step)
# step 9133 - loss = 0.000, (0.472 sec/step)
# step 9134 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 9135 - loss = 0.000, (3.521 sec/step)
# step 9136 - loss = 0.000, (0.482 sec/step)
# step 9137 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 9138 - loss = 0.000, (3.499 sec/step)
# step 9139 - loss = 0.000, (0.474 sec/step)
# step 9140 - loss = 0.000, (0.342 sec/step)
# files length: 1
# step 9141 - loss = 0.000, (3.486 sec/step)
# step 9142 - loss = 0.000, (0.485 sec/step)
# step 9143 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9144 - loss = 0.000, (3.605 sec/step)
# step 9145 - loss = 0.000, (0.474 sec/step)
# step 9146 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9147 - loss = 0.000, (3.525 sec/step)
# step 9148 - loss = 0.000, (0.477 sec/step)
# step 9149 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 9150 - loss = 0.000, (3.516 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# step 9151 - loss = 0.000, (0.472 sec/step)
# step 9152 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 9153 - loss = 0.000, (1.997 sec/step)
# step 9154 - loss = 0.000, (0.474 sec/step)
# step 9155 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9156 - loss = 0.000, (3.457 sec/step)
# step 9157 - loss = 0.000, (0.474 sec/step)
# step 9158 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 9159 - loss = 0.000, (3.521 sec/step)
# step 9160 - loss = 0.000, (0.467 sec/step)
# step 9161 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 9162 - loss = 0.000, (3.507 sec/step)
# step 9163 - loss = 0.000, (0.471 sec/step)
# step 9164 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 9165 - loss = 0.000, (3.521 sec/step)
# step 9166 - loss = 0.000, (0.472 sec/step)
# step 9167 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9168 - loss = 0.000, (3.378 sec/step)
# step 9169 - loss = 0.000, (0.476 sec/step)
# step 9170 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 9171 - loss = 0.000, (3.485 sec/step)
# step 9172 - loss = 0.000, (0.473 sec/step)
# step 9173 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 9174 - loss = 0.000, (3.505 sec/step)
# step 9175 - loss = 0.000, (0.470 sec/step)
# step 9176 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 9177 - loss = 0.000, (3.480 sec/step)
# step 9178 - loss = 0.000, (0.476 sec/step)
# step 9179 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 9180 - loss = 0.000, (3.374 sec/step)
# step 9181 - loss = 0.000, (0.475 sec/step)
# step 9182 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 9183 - loss = 0.000, (3.516 sec/step)
# step 9184 - loss = 0.000, (0.470 sec/step)
# step 9185 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9186 - loss = 0.000, (3.461 sec/step)
# step 9187 - loss = 0.000, (0.470 sec/step)
# step 9188 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 9189 - loss = 0.000, (3.433 sec/step)
# step 9190 - loss = 0.000, (0.473 sec/step)
# step 9191 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 9192 - loss = 0.000, (3.637 sec/step)
# step 9193 - loss = 0.000, (0.475 sec/step)
# step 9194 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9195 - loss = 0.000, (3.459 sec/step)
# step 9196 - loss = 0.000, (0.476 sec/step)
# step 9197 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 9198 - loss = 0.000, (3.593 sec/step)
# step 9199 - loss = 0.000, (0.473 sec/step)
# step 9200 - loss = 0.000, (0.338 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.
# files length: 1
# step 9201 - loss = 0.000, (1.893 sec/step)
# step 9202 - loss = 0.000, (0.470 sec/step)
# step 9203 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 9204 - loss = 0.000, (3.535 sec/step)
# step 9205 - loss = 0.000, (0.471 sec/step)
# step 9206 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 9207 - loss = 0.000, (3.541 sec/step)
# step 9208 - loss = 0.000, (0.471 sec/step)
# step 9209 - loss = 0.000, (0.336 sec/step)
# files length: 1
# step 9210 - loss = 0.000, (3.481 sec/step)
# step 9211 - loss = 0.000, (0.481 sec/step)
# step 9212 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9213 - loss = 0.000, (3.400 sec/step)
# step 9214 - loss = 0.000, (0.477 sec/step)
# step 9215 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 9216 - loss = 0.000, (3.428 sec/step)
# step 9217 - loss = 0.000, (0.477 sec/step)
# step 9218 - loss = 0.000, (0.338 sec/step)
# files length: 1
# step 9219 - loss = 0.000, (3.503 sec/step)
# step 9220 - loss = 0.000, (0.470 sec/step)
# step 9221 - loss = 0.000, (0.337 sec/step)
# files length: 1
# step 9222 - loss = 0.000, (3.620 sec/step)
# step 9223 - loss = 0.000, (0.470 sec/step)
# step 9224 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9225 - loss = 0.000, (3.387 sec/step)
# step 9226 - loss = 0.000, (0.473 sec/step)
# step 9227 - loss = 0.000, (0.343 sec/step)
# files length: 1
# step 9228 - loss = 0.000, (3.388 sec/step)
# step 9229 - loss = 0.000, (0.475 sec/step)
# step 9230 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 9231 - loss = 0.000, (3.415 sec/step)
# step 9232 - loss = 0.000, (0.474 sec/step)
# step 9233 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9234 - loss = 0.000, (3.513 sec/step)
# step 9235 - loss = 0.000, (0.468 sec/step)
# step 9236 - loss = 0.000, (0.339 sec/step)
# files length: 1
# step 9237 - loss = 0.000, (3.387 sec/step)
# step 9238 - loss = 0.000, (0.472 sec/step)
# step 9239 - loss = 0.000, (0.347 sec/step)
# files length: 1
# step 9240 - loss = 0.000, (3.412 sec/step)
# step 9241 - loss = 0.000, (0.476 sec/step)
# step 9242 - loss = 0.000, (0.340 sec/step)
# files length: 1
# step 9243 - loss = 0.000, (3.607 sec/step)
# step 9244 - loss = 0.000, (0.476 sec/step)
# step 9245 - loss = 0.000, (0.343 sec/step)
# files length: 1
# step 9246 - loss = 0.000, (3.464 sec/step)
# step 9247 - loss = 0.000, (0.477 sec/step)
# step 9248 - loss = 0.000, (0.341 sec/step)
# files length: 1
# step 9249 - loss = 0.000, (3.539 sec/step)
# Storing checkpoint to ./logdir/train/2020-06-24T22-48-57 ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'filter_bias' has type str, but expected one of: int, long, bool
#  Done.

# %%
# !cd gdrive/My\ Drive/tensorflow-wavenet-new && python generate.py --wav_out_path=generated_short.wav --save_every 4000 --samples=32000 logdir/train/2020-06-24T22-48-57/model.ckpt-9249
# Out:
# 2020-06-25 02:42:49.735783: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2020-06-25 02:42:51.641775: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-06-25 02:42:51.645209: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-25 02:42:51.646013: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-06-25 02:42:51.646067: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-25 02:42:51.648043: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-06-25 02:42:51.650191: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-06-25 02:42:51.650564: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-06-25 02:42:51.652671: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-06-25 02:42:51.653731: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-06-25 02:42:51.658263: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-06-25 02:42:51.658491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-25 02:42:51.659371: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-25 02:42:51.660060: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-06-25 02:42:51.666536: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-06-25 02:42:51.666810: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x60eaa80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-06-25 02:42:51.666857: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-06-25 02:42:51.718098: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-25 02:42:51.718978: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x60eac40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-06-25 02:42:51.719024: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-06-25 02:42:51.719365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-25 02:42:51.720083: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-06-25 02:42:51.720158: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-25 02:42:51.720217: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-06-25 02:42:51.720264: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-06-25 02:42:51.720308: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-06-25 02:42:51.720365: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-06-25 02:42:51.720410: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-06-25 02:42:51.720454: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-06-25 02:42:51.720595: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-25 02:42:51.721399: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-25 02:42:51.722105: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-06-25 02:42:51.722178: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-25 02:42:52.156482: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-06-25 02:42:52.156558: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-06-25 02:42:52.156577: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-06-25 02:42:52.157014: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-25 02:42:52.157850: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-25 02:42:52.158572: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-06-25 02:42:52.158633: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10520 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /content/gdrive/My Drive/tensorflow-wavenet-new/wavenet/model.py:27: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Restoring model from logdir/train/2020-06-24T22-48-57/model.ckpt-9249
# 2020-06-25 02:42:58.670714: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# Updated wav file at generated_short.wav
# Updated wav file at generated_short.wav
# Updated wav file at generated_short.wav
# Updated wav file at generated_short.wav
# Updated wav file at generated_short.wav
# Updated wav file at generated_short.wav

# %%
##makes code tf2 compatible

# !tf_upgrade_v2 --intree gdrive/My\ Drive/tensorflow-wavenet/ --outtree gdrive/My\ Drive/tensorflow-wavenet/new
# Out:
# INFO line 128:16: Added keywords to args of function 'tf.cond'
# INFO line 128:24: Added keywords to args of function 'tf.size'
# INFO line 129:32: Added keywords to args of function 'tf.size'
# INFO line 142:11: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 158:14: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 166:17: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 170:38: Renamed 'tf.global_variables' to 'tf.compat.v1.global_variables'
# INFO line 172:12: Renamed 'tf.train.Saver' to 'tf.compat.v1.train.Saver'
# INFO line 263:13: tf.summary.FileWriter requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 263:13: Renamed 'tf.summary.FileWriter' to 'tf.compat.v1.summary.FileWriter'
# INFO line 264:4: tf.summary.audio requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 264:4: Renamed 'tf.summary.audio' to 'tf.compat.v1.summary.audio'
# INFO line 265:16: tf.summary.merge_all requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 265:16: Renamed 'tf.summary.merge_all' to 'tf.compat.v1.summary.merge_all'
# WARNING line 118:4: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
# INFO line 212:9: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 212:9: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 259:16: Renamed 'tf.trainable_variables' to 'tf.compat.v1.trainable_variables'
# INFO line 263:13: tf.summary.FileWriter requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 263:13: Renamed 'tf.summary.FileWriter' to 'tf.compat.v1.summary.FileWriter'
# INFO line 264:21: Renamed 'tf.get_default_graph' to 'tf.compat.v1.get_default_graph'
# INFO line 265:19: Renamed 'tf.RunMetadata' to 'tf.compat.v1.RunMetadata'
# INFO line 266:16: tf.summary.merge_all requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 266:16: Renamed 'tf.summary.merge_all' to 'tf.compat.v1.summary.merge_all'
# INFO line 269:11: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 269:29: Renamed 'tf.ConfigProto' to 'tf.compat.v1.ConfigProto'
# INFO line 270:11: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 274:12: Renamed 'tf.train.Saver' to 'tf.compat.v1.train.Saver'
# INFO line 274:36: Renamed 'tf.trainable_variables' to 'tf.compat.v1.trainable_variables'
# INFO line 289:14: Renamed 'tf.train.start_queue_runners' to 'tf.compat.v1.train.start_queue_runners'
# INFO line 300:30: Renamed 'tf.RunOptions' to 'tf.compat.v1.RunOptions'
# INFO line 301:32: Renamed 'tf.RunOptions' to 'tf.compat.v1.RunOptions'
# INFO line 22:19: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 28:21: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 37:19: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 43:21: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 51:19: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 57:21: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 96:26: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 97:21: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 196:16: Renamed 'tf.train.Saver' to 'tf.compat.v1.train.Saver'
# INFO line 196:40: Renamed 'tf.trainable_variables' to 'tf.compat.v1.trainable_variables'
# WARNING line 197:8: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
# INFO line 231:28: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 232:25: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 239:20: Renamed 'tf.trainable_variables' to 'tf.compat.v1.trainable_variables'
# INFO line 241:15: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# INFO line 7:11: Renamed 'tf.train.AdamOptimizer' to 'tf.compat.v1.train.AdamOptimizer'
# INFO line 12:11: Renamed 'tf.train.MomentumOptimizer' to 'tf.compat.v1.train.MomentumOptimizer'
# INFO line 17:11: Renamed 'tf.train.RMSPropOptimizer' to 'tf.compat.v1.train.RMSPropOptimizer'
# INFO line 28:9: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 28:9: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 29:16: Added keywords to args of function 'tf.shape'
# INFO line 31:17: Added keywords to args of function 'tf.pad'
# INFO line 33:21: Added keywords to args of function 'tf.transpose'
# INFO line 38:9: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 38:9: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 39:16: Added keywords to args of function 'tf.shape'
# INFO line 41:21: Added keywords to args of function 'tf.transpose'
# INFO line 43:27: Renamed 'tf.div' to 'tf.compat.v1.div'
# INFO line 47:9: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 47:9: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 48:23: Added keywords to args of function 'tf.shape'
# INFO line 51:19: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 51:19: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 55:23: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 55:23: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 57:20: Added keywords to args of function 'tf.shape'
# INFO line 66:9: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 66:9: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 67:13: Changed tf.to_float call to tf.cast(..., dtype=tf.float32).
# INFO line 72:20: Renamed 'tf.log1p' to 'tf.math.log1p'
# INFO line 72:52: Renamed 'tf.log1p' to 'tf.math.log1p'
# INFO line 75:15: Changed tf.to_int32 call to tf.cast(..., dtype=tf.int32).
# INFO line 80:9: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 80:9: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 83:22: Changed tf.to_float call to tf.cast(..., dtype=tf.float32).
# INFO line 9:0: Not upgrading symbols because `tensorflow.compat.v1` was directly imported as `tf`.
# INFO line 10:18: Changing tf.contrib.layers xavier initializer to a tf.compat.v1.keras.initializers.VarianceScaling and converting arguments.
#
# INFO line 27:18: tf.constant_initializer requires manual check. Initializers no longer have the dtype argument in the constructor or partition_info argument in the __call__ method.
# The calls have been converted to compat.v1 for safety (even though they may already have been correct).
# INFO line 27:18: Renamed 'tf.constant_initializer' to 'tf.compat.v1.constant_initializer'
# INFO line 134:13: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 142:21: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 150:17: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 166:17: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 168:25: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 217:17: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 241:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 241:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 283:40: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 283:40: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 289:36: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 289:36: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 305:22: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 305:22: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 309:19: Added keywords to args of function 'tf.shape'
# INFO line 312:28: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 312:28: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 333:20: Added keywords to args of function 'tf.shape'
# INFO line 333:47: Added keywords to args of function 'tf.shape'
# INFO line 348:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 348:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 403:23: Added keywords to args of function 'tf.shape'
# INFO line 406:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 406:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 408:21: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 408:21: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 414:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 414:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 434:20: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 434:20: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 438:20: Added keywords to args of function 'tf.nn.conv1d'
# INFO line 438:20: Renamed keyword argument for tf.nn.conv1d from value to input
# INFO line 451:12: Renamed 'tf.FIFOQueue' to 'tf.queue.FIFOQueue'
# INFO line 467:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 467:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 469:21: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 469:21: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 471:24: Renamed 'tf.FIFOQueue' to 'tf.queue.FIFOQueue'
# INFO line 491:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 491:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 522:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 522:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 543:24: Added keywords to args of function 'tf.nn.embedding_lookup'
# WARNING line 543:24: tf.nn.embedding_lookup requires manual check. `partition_strategy` has been removed from tf.nn.embedding_lookup.  The 'div' strategy will be used by default.
# INFO line 573:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 573:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 588:17: Added keywords to args of function 'tf.shape'
# INFO line 603:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 603:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 613:17: Added keywords to args of function 'tf.shape'
# INFO line 626:13: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 626:13: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 641:34: Added keywords to args of function 'tf.shape'
# INFO line 647:17: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 647:17: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 660:23: Changing labels arg of tf.nn.softmax_cross_entropy_with_logits to tf.stop_gradient(labels). Please check this transformation.
#
# INFO line 663:31: Added keywords to args of function 'tf.reduce_mean'
# INFO line 665:16: tf.summary.scalar requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 665:16: Renamed 'tf.summary.scalar' to 'tf.compat.v1.summary.scalar'
# INFO line 672:49: Renamed 'tf.trainable_variables' to 'tf.compat.v1.trainable_variables'
# INFO line 679:20: tf.summary.scalar requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 679:20: Renamed 'tf.summary.scalar' to 'tf.compat.v1.summary.scalar'
# INFO line 680:20: tf.summary.scalar requires manual check. The TF 1.x summary API cannot be automatically migrated to TF 2.0, so symbols have been converted to tf.compat.v1.summary.* and must be migrated manually. Typical usage will only require changes to the summary writing logic, not to individual calls like scalar(). For examples of the new summary API, see the Effective TF 2.0 migration document or check the TF 2.0 TensorBoard tutorials.
# INFO line 680:20: Renamed 'tf.summary.scalar' to 'tf.compat.v1.summary.scalar'
# TensorFlow 2.0 Upgrade Script
# -----------------------------
# Converted 10 files
# Detected 3 issues that require attention
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# File: gdrive/My Drive/tensorflow-wavenet/train.py
# --------------------------------------------------------------------------------
# gdrive/My Drive/tensorflow-wavenet/train.py:118:4: WARNING: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
# --------------------------------------------------------------------------------
# File: gdrive/My Drive/tensorflow-wavenet/wavenet/model.py
# --------------------------------------------------------------------------------
# gdrive/My Drive/tensorflow-wavenet/wavenet/model.py:543:24: WARNING: tf.nn.embedding_lookup requires manual check. `partition_strategy` has been removed from tf.nn.embedding_lookup.  The 'div' strategy will be used by default.
# --------------------------------------------------------------------------------
# File: gdrive/My Drive/tensorflow-wavenet/test/test_model.py
# --------------------------------------------------------------------------------
# gdrive/My Drive/tensorflow-wavenet/test/test_model.py:197:8: WARNING: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
#
#
# Make sure to read the detailed log 'report.txt'
